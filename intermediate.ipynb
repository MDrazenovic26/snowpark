# %%
# Import login values from config
from configparser import *

# %%
# Import packages needed
from snowflake.snowpark import Session
from snowflake.snowpark.functions import *
from snowflake.snowpark.types import StringType, ArrayType
from snowflake.snowpark import Window
import pandas as pd
from urllib import request
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re

# %%
import sys, json
with open("connection_parameters_true.json") as jsonfile:
    credentials_dict = json.load(jsonfile)

# %%
def snowpark_session_create():
    session = Session.builder.configs(credentials_dict).create()
    return session

# %%
# Creation of session using the above function
demo_session = snowpark_session_create()

# %%
# TODO: Replace with values relevant to you
demo_session.use_database("snowpark")
demo_session.use_schema("gold")

# %% [markdown]
# ## Pandas

# %%
# Creation of a Pandas DataFrame
data = {
    'id' : [1,2,3,4,5],
    'website' : [
        'https://en.wikipedia.org/wiki/Snowflake_Inc',
        'https://en.wikipedia.org/wiki/Amazon_Web_Services',
        'https://en.wikipedia.org/wiki/Google_Cloud_Platform',
        'https://en.wikipedia.org/wiki/Microsoft_Azure',
        'https://en.wikipedia.org/wiki/Apache_Spark',
    ],
    'html' : []
}

for item in data['website']:
    response = urlopen(item)
    html_content = response.read().decode('utf-8')
    #data['html'].append(request.urlopen(item).read())
    data['html'].append(html_content)

pdDataFrame = pd.DataFrame.from_dict(data)

# %%
# See Pandas DataFrame
pdDataFrame
# Out:
#    id                                            website  \
# 0   1        https://en.wikipedia.org/wiki/Snowflake_Inc
# 1   2  https://en.wikipedia.org/wiki/Amazon_Web_Services
# 2   3  https://en.wikipedia.org/wiki/Google_Cloud_Pla...
# 3   4      https://en.wikipedia.org/wiki/Microsoft_Azure
# 4   5         https://en.wikipedia.org/wiki/Apache_Spark
#
#                                                 html
# 0  <!DOCTYPE html>\n<html class="client-nojs vect...
# 1  <!DOCTYPE html>\n<html class="client-nojs vect...
# 2  <!DOCTYPE html>\n<html class="client-nojs vect...
# 3  <!DOCTYPE html>\n<html class="client-nojs vect...
# 4  <!DOCTYPE html>\n<html class="client-nojs vect...

# %%
# TODO: Run the below code to create the table
demo_session.sql(
    """
    create or replace table wikipedia_pages (
    id int,
    website string,
    html string
    )

    """
).collect()
# Out:
# [Row(status='Table WIKIPEDIA_PAGES successfully created.')]

# %%
# TODO: Create a dataframe that writes the pandas dataframe to a table in Snowflake
spDataFrame = demo_session.write_pandas(
    df = pdDataFrame,
    table_name="wikipedia_pages",
    database= "snowpark",
    schema="gold",
    quote_identifiers=False,
    overwrite=True
)

# %%
# TODO: Show that table
spDataFrame.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------
# |"ID"  |"WEBSITE"                                           |"HTML"                                              |
# ------------------------------------------------------------------------------------------------------------------
# |1     |https://en.wikipedia.org/wiki/Snowflake_Inc         |<!DOCTYPE html>                                     |
# |      |                                                    |<html class="client-nojs vector-feature-languag...  |
# |      |                                                    |<head>                                              |
# |      |                                                    |<meta charset="UTF-8">                              |
# |      |                                                    |<title>Snowflake Inc. - Wikipedia</title>           |
# |      |                                                    |<script>(function(){var className="client-js ve...  |
# |      |                                                    |"September","October","November","December"],"w...  |
# |      |                                                    |"Data warehousing products","Cloud databases","...  |
# |      |                                                    |"wgInternalRedirectTargetUrl":"/wiki/Snowflake_...  |
# |      |                                                    |"ext.uls.interlanguage":"ready","wikibase.clien...  |
# |      |                                                    |<script>(RLQ=window.RLQ||[]).push(function(){mw...  |
# |      |                                                    |}];});});</script>                                  |
# |      |                                                    |<link rel="stylesheet" href="/w/load.php?lang=e...  |
# |      |                                                    |<script async="" src="/w/load.php?lang=en&amp;m...  |
# |      |                                                    |<meta name="ResourceLoaderDynamicStyles" conten...  |
# |      |                                                    |<link rel="stylesheet" href="/w/load.php?lang=e...  |
# |      |                                                    |<meta name="generator" content="MediaWiki 1.41....  |
# |      |                                                    |<meta name="referrer" content="origin">             |
# |      |                                                    |<meta name="referrer" content="origin-when-cros...  |
# |      |                                                    |<meta name="referrer" content="origin-when-cros...  |
# |      |                                                    |<meta name="robots" content="max-image-preview:...  |
# |      |                                                    |<meta name="format-detection" content="telephon...  |
# |      |                                                    |<meta name="viewport" content="width=1000">         |
# |      |                                                    |<meta property="og:title" content="Snowflake In...  |
# |      |                                                    |<meta property="og:type" content="website">         |
# |      |                                                    |<link rel="preconnect" href="//upload.wikimedia...  |
# |      |                                                    |<link rel="alternate" media="only screen and (m...  |
# |      |                                                    |<link rel="alternate" type="application/x-wiki"...  |
# |      |                                                    |<link rel="apple-touch-icon" href="/static/appl...  |
# |      |                                                    |<link rel="icon" href="/static/favicon/wikipedi...  |
# |      |                                                    |<link rel="search" type="application/opensearch...  |
# |      |                                                    |<link rel="EditURI" type="application/rsd+xml" ...  |
# |      |                                                    |<link rel="canonical" href="https://en.wikipedi...  |
# |      |                                                    |<link rel="license" href="https://creativecommo...  |
# |      |                                                    |<link rel="alternate" type="application/atom+xm...  |
# |      |                                                    |<link rel="dns-prefetch" href="//meta.wikimedia...  |
# |      |                                                    |<link rel="dns-prefetch" href="//login.wikimedi...  |
# |      |                                                    |</head>                                             |
# |      |                                                    |<body class="skin-vector skin-vector-search-vue...  |
# |      |                                                    |<div class="vector-header-container">               |
# |      |                                                    |	<header class="vector-header mw-header">           |
# |      |                                                    |		<div class="vector-header-start">                 |
# |      |                                                    |			<nav class="vector-main-menu-landmark" aria-...  |
# |      |                                                    |				                                                |
# |      |                                                    |<div id="vector-main-menu-dropdown" class="vect...  |
# |      |                                                    |	<input type="checkbox" id="vector-main-menu-dr...  |
# |      |                                                    |	<label id="vector-main-menu-dropdown-label" fo...  |
# |      |                                                    |                                                    |
# |      |                                                    |<span class="vector-dropdown-label-text">Main m...  |
# |      |                                                    |	</label>                                           |
# |      |                                                    |	<div class="vector-dropdown-content">              |
# |      |                                                    |                                                    |
# |      |                                                    |                                                    |
# |      |                                                    |				<div id="vector-main-menu-unpinned-containe...  |
# |      |                                                    |		                                                  |
# |      |                                                    |<div id="vector-main-menu" class="vector-main-m...  |
# |      |                                                    |	<div                                               |
# |      |                                                    |	class="vector-pinnable-header vector-main-menu...  |
# |      |                                                    |	data-feature-name="main-menu-pinned"               |
# |      |                                                    |	data-pinnable-element-id="vector-main-menu"        |
# |      |                                                    |	data-pinned-container-id="vector-main-menu-pin...  |
# |      |                                                    |	data-unpinned-container-id="vector-main-menu-u...  |
# |      |                                                    |>                                                   |
# |      |                                                    |	<div class="vector-pinnable-header-label">Main...  |
# |      |                                                    |	<button class="vector-pinnable-header-toggle-b...  |
# |      |                                                    |	<button class="vector-pinnable-header-toggle-b...  |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |	                                                   |
# |      |                                                    |<div id="p-navigation" class="vector-menu mw-po...  |
# |      |                                                    |	<div class="vector-menu-heading">                  |
# |      |                                                    |		Navigation                                        |
# |      |                                                    |	</div>                                             |
# |      |                                                    |	<div class="vector-menu-content">                  |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul class="vector-menu-content-list">             |
# |      |                                                    |			                                                 |
# |      |                                                    |			<li id="n-mainpage-description" class="mw-li...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |	                                                   |
# |      |                                                    |	                                                   |
# |      |                                                    |<div id="p-interaction" class="vector-menu mw-p...  |
# |      |                                                    |	<div class="vector-menu-heading">                  |
# |      |                                                    |		Contribute                                        |
# |      |                                                    |	</div>                                             |
# |      |                                                    |	<div class="vector-menu-content">                  |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul class="vector-menu-content-list">             |
# |      |                                                    |			                                                 |
# |      |                                                    |			<li id="n-help" class="mw-list-item"><a href...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |	                                                   |
# |      |                                                    |<div class="vector-main-menu-action vector-main...  |
# |      |                                                    |	<div class="vector-main-menu-action-item">         |
# |      |                                                    |		<div class="vector-main-menu-action-heading v...  |
# |      |                                                    |		<div class="vector-main-menu-action-content v...  |
# |      |                                                    |			<div class="mw-message-box cdx-message cdx-m...  |
# |      |                                                    |		</div>                                            |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |				</div>                                          |
# |      |                                                    |                                                    |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |		</nav>                                            |
# |      |                                                    |			                                                 |
# |      |                                                    |<a href="/wiki/Main_Page" class="mw-logo">          |
# |      |                                                    |	<img class="mw-logo-icon" src="/static/images/...  |
# |      |                                                    |	<span class="mw-logo-container">                   |
# |      |                                                    |		<img class="mw-logo-wordmark" alt="Wikipedia"...  |
# |      |                                                    |		<img class="mw-logo-tagline" alt="The Free En...  |
# |      |                                                    |	</span>                                            |
# |      |                                                    |</a>                                                |
# |      |                                                    |                                                    |
# |      |                                                    |		</div>                                            |
# |      |                                                    |		<div class="vector-header-end">                   |
# |      |                                                    |			                                                 |
# |      |                                                    |<div id="p-search" role="search" class="vector-...  |
# |      |                                                    |	<a href="/wiki/Special:Search" class="cdx-butt...  |
# |      |                                                    |                                                    |
# |      |                                                    |<span>Search</span>                                 |
# |      |                                                    |	</a>                                               |
# |      |                                                    |	<div class="vector-typeahead-search-container">    |
# |      |                                                    |		<div class="cdx-typeahead-search cdx-typeahea...  |
# |      |                                                    |			<form action="/w/index.php" id="searchform" ...  |
# |      |                                                    |				<div id="simpleSearch" class="cdx-search-in...  |
# |      |                                                    |					<div class="cdx-text-input cdx-text-input-...  |
# |      |                                                    |						<input                                        |
# |      |                                                    |							class="cdx-text-input__input"                |
# |      |                                                    |							 type="search" name="search" placeholder...  |
# |      |                                                    |							>                                            |
# |      |                                                    |						<span class="cdx-text-input__icon cdx-tex...  |
# |      |                                                    |					</div>                                         |
# |      |                                                    |					<input type="hidden" name="title" value="S...  |
# |      |                                                    |				</div>                                          |
# |      |                                                    |				<button class="cdx-button cdx-search-input_...  |
# |      |                                                    |			</form>                                          |
# |      |                                                    |		</div>                                            |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |			<nav class="vector-user-links" aria-label="P...  |
# |      |                                                    |	                                                   |
# |      |                                                    |<div id="p-vector-user-menu-overflow" class="ve...  |
# |      |                                                    |	<div class="vector-menu-content">                  |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul class="vector-menu-content-list">             |
# |      |                                                    |			                                                 |
# |      |                                                    |			<li id="pt-createaccount-2" class="user-link...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |	                                                   |
# |      |                                                    |<div id="vector-user-links-dropdown" class="vec...  |
# |      |                                                    |	<input type="checkbox" id="vector-user-links-d...  |
# |      |                                                    |	<label id="vector-user-links-dropdown-label" f...  |
# |      |                                                    |                                                    |
# |      |                                                    |<span class="vector-dropdown-label-text">Person...  |
# |      |                                                    |	</label>                                           |
# |      |                                                    |	<div class="vector-dropdown-content">              |
# |      |                                                    |                                                    |
# |      |                                                    |                                                    |
# |      |                                                    |		                                                  |
# |      |                                                    |<div id="p-personal" class="vector-menu mw-port...  |
# |      |                                                    |	<div class="vector-menu-content">                  |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul class="vector-menu-content-list">             |
# |      |                                                    |			                                                 |
# |      |                                                    |			<li id="pt-createaccount" class="user-links-...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |<div id="p-user-menu-anon-editor" class="vector...  |
# |      |                                                    |	<div class="vector-menu-heading">                  |
# |      |                                                    |		Pages for logged out editors <a href="/wiki/H...  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |	<div class="vector-menu-content">                  |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul class="vector-menu-content-list">             |
# |      |                                                    |			                                                 |
# |      |                                                    |			<li id="pt-anoncontribs" class="mw-list-item...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |	                                                   |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |</nav>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |		</div>                                            |
# |      |                                                    |	</header>                                          |
# |      |                                                    |</div>                                              |
# |      |                                                    |<div class="mw-page-container">                     |
# |      |                                                    |	<div class="mw-page-container-inner">              |
# |      |                                                    |		<div class="vector-main-menu-container ">         |
# |      |                                                    |			<div id="mw-navigation">                         |
# |      |                                                    |				<nav id="mw-panel" class="vector-main-menu-...  |
# |      |                                                    |					<div id="vector-main-menu-pinned-container...  |
# |      |                                                    |				                                                |
# |      |                                                    |					</div>                                         |
# |      |                                                    |		</nav>                                            |
# |      |                                                    |			</div>                                           |
# |      |                                                    |		</div>                                            |
# |      |                                                    |		<div class="vector-sitenotice-container">         |
# |      |                                                    |			<div id="siteNotice"><!-- CentralNotice --><...  |
# |      |                                                    |		</div>                                            |
# |      |                                                    |		<input type="checkbox" id="vector-toc-collaps...  |
# |      |                                                    |		<nav id="mw-panel-toc" role="navigation" aria...  |
# |      |                                                    |			<div id="vector-toc-pinned-container" class=...  |
# |      |                                                    |					<div id="vector-toc" class="vector-toc vec...  |
# |      |                                                    |	<div                                               |
# |      |                                                    |	class="vector-pinnable-header vector-toc-pinna...  |
# |      |                                                    |	data-feature-name="toc-pinned"                     |
# |      |                                                    |	data-pinnable-element-id="vector-toc"              |
# |      |                                                    |	                                                   |
# |      |                                                    |	                                                   |
# |      |                                                    |>                                                   |
# |      |                                                    |	<h2 class="vector-pinnable-header-label">Conte...  |
# |      |                                                    |	<button class="vector-pinnable-header-toggle-b...  |
# |      |                                                    |	<button class="vector-pinnable-header-toggle-b...  |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |                                                    |
# |      |                                                    |	<ul class="vector-toc-contents" id="mw-panel-t...  |
# |      |                                                    |		<li id="toc-mw-content-text"                      |
# |      |                                                    |			class="vector-toc-list-item vector-toc-level...  |
# |      |                                                    |			<a href="#" class="vector-toc-link">             |
# |      |                                                    |				<div class="vector-toc-text">(Top)</div>        |
# |      |                                                    |			</a>                                             |
# |      |                                                    |		</li>                                             |
# |      |                                                    |		<li id="toc-History"                              |
# |      |                                                    |		class="vector-toc-list-item vector-toc-level-...  |
# |      |                                                    |		<a class="vector-toc-link" href="#History">       |
# |      |                                                    |			<div class="vector-toc-text">                    |
# |      |                                                    |			<span class="vector-toc-numb">1</span>Histor...  |
# |      |                                                    |		</a>                                              |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul id="toc-History-sublist" class="vector-to...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |	</li>                                              |
# |      |                                                    |	<li id="toc-References"                            |
# |      |                                                    |		class="vector-toc-list-item vector-toc-level-...  |
# |      |                                                    |		<a class="vector-toc-link" href="#References">    |
# |      |                                                    |			<div class="vector-toc-text">                    |
# |      |                                                    |			<span class="vector-toc-numb">2</span>Refere...  |
# |      |                                                    |		</a>                                              |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul id="toc-References-sublist" class="vector...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |	</li>                                              |
# |      |                                                    |	<li id="toc-External_links"                        |
# |      |                                                    |		class="vector-toc-list-item vector-toc-level-...  |
# |      |                                                    |		<a class="vector-toc-link" href="#External_li...  |
# |      |                                                    |			<div class="vector-toc-text">                    |
# |      |                                                    |			<span class="vector-toc-numb">3</span>Extern...  |
# |      |                                                    |		</a>                                              |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul id="toc-External_links-sublist" class="ve...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |	</li>                                              |
# |      |                                                    |</ul>                                               |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |			</div>                                           |
# |      |                                                    |		</nav>                                            |
# |      |                                                    |		<div class="mw-content-container">                |
# |      |                                                    |			<main id="content" class="mw-body" role="main">  |
# |      |                                                    |				<header class="mw-body-header vector-page-t...  |
# |      |                                                    |					<label                                         |
# |      |                                                    |						id="vector-toc-collapsed-button"              |
# |      |                                                    |						class="cdx-button cdx-button--fake-button...  |
# |      |                                                    |						for="vector-toc-collapsed-checkbox"           |
# |      |                                                    |						role="button"                                 |
# |      |                                                    |						aria-controls="vector-toc"                    |
# |      |                                                    |						tabindex="0"                                  |
# |      |                                                    |						title="Table of Contents">                    |
# |      |                                                    |						<span class="vector-icon mw-ui-icon-wikim...  |
# |      |                                                    |						<span>Toggle the table of contents</span>     |
# |      |                                                    |					</label>                                       |
# |      |                                                    |					<nav role="navigation" aria-label="Content...  |
# |      |                                                    |						                                              |
# |      |                                                    |<div id="vector-page-titlebar-toc" class="vecto...  |
# |      |                                                    |	<input type="checkbox" id="vector-page-titleba...  |
# |      |                                                    |	<label id="vector-page-titlebar-toc-label" for...  |
# |      |                                                    |                                                    |
# |      |                                                    |<span class="vector-dropdown-label-text">Toggle...  |
# |      |                                                    |	</label>                                           |
# |      |                                                    |	<div class="vector-dropdown-content">              |
# |      |                                                    |                                                    |
# |      |                                                    |                                                    |
# |      |                                                    |							<div id="vector-page-titlebar-toc-unpinn...  |
# |      |                                                    |			</div>                                           |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |					</nav>                                         |
# |      |                                                    |					<h1 id="firstHeading" class="firstHeading ...  |
# |      |                                                    |							                                             |
# |      |                                                    |<div id="p-lang-btn" class="vector-dropdown mw-...  |
# |      |                                                    |	<input type="checkbox" id="p-lang-btn-checkbox...  |
# |      |                                                    |	<label id="p-lang-btn-label" for="p-lang-btn-c...  |
# |      |                                                    |                                                    |
# |      |                                                    |<span class="vector-dropdown-label-text">7 lang...  |
# |      |                                                    |	</label>                                           |
# |      |                                                    |	<div class="vector-dropdown-content">              |
# |      |                                                    |                                                    |
# |      |                                                    |		<div class="vector-menu-content">                 |
# |      |                                                    |			                                                 |
# |      |                                                    |			<ul class="vector-menu-content-list">            |
# |      |                                                    |				                                                |
# |      |                                                    |				<li class="interlanguage-link interwiki-de ...  |
# |      |                                                    |			</ul>                                            |
# |      |                                                    |			<div class="after-portlet after-portlet-lang...  |
# |      |                                                    |		</div>                                            |
# |      |                                                    |                                                    |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |</header>                                           |
# |      |                                                    |				<div class="vector-page-toolbar">               |
# |      |                                                    |					<div class="vector-page-toolbar-container">    |
# |      |                                                    |						<div id="left-navigation">                    |
# |      |                                                    |							<nav aria-label="Namespaces">                |
# |      |                                                    |								                                            |
# |      |                                                    |<div id="p-associated-pages" class="vector-menu...  |
# |      |                                                    |	<div class="vector-menu-content">                  |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul class="vector-menu-content-list">             |
# |      |                                                    |			                                                 |
# |      |                                                    |			<li id="ca-nstab-main" class="selected vecto...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |								                                            |
# |      |                                                    |<div id="p-variants" class="vector-dropdown emp...  |
# |      |                                                    |	<input type="checkbox" id="p-variants-checkbox...  |
# |      |                                                    |	<label id="p-variants-label" for="p-variants-c...  |
# |      |                                                    |	</label>                                           |
# |      |                                                    |	<div class="vector-dropdown-content">              |
# |      |                                                    |                                                    |
# |      |                                                    |                                                    |
# |      |                                                    |					                                               |
# |      |                                                    |<div id="p-variants" class="vector-menu mw-port...  |
# |      |                                                    |	<div class="vector-menu-content">                  |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul class="vector-menu-content-list">             |
# |      |                                                    |			                                                 |
# |      |                                                    |			                                                 |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |				                                                |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |							</nav>                                       |
# |      |                                                    |						</div>                                        |
# |      |                                                    |						<div id="right-navigation" class="vector-...  |
# |      |                                                    |							<nav aria-label="Views">                     |
# |      |                                                    |								                                            |
# |      |                                                    |<div id="p-views" class="vector-menu vector-men...  |
# |      |                                                    |	<div class="vector-menu-content">                  |
# |      |                                                    |		                                                  |
# |      |                                                    |		<ul class="vector-menu-content-list">             |
# |      |                                                    |			                                                 |
# |      |                                                    |			<li id="ca-view" class="selected vector-tab-...  |
# |      |                                                    |		</ul>                                             |
# |      |                                                    |		                                                  |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |                                                    |
# |      |                                                    |							</nav>                                       |
# |      |                                                    |				                                                |
# |      |                                                    |							<nav class="vector-page-tools-landmark" ...  |
# |      |                                                    |								                                            |
# |      |                                                    |<div id="vector-page-tools-dropdown" class="vec...  |
# |      |                                                    |	<input type="checkbox" id="vector-page-tools-d...  |
# |      |                                                    |	<label id="vector-page-tools-dropdown-label" f...  |
# |      |                                                    |	</label>                                           |
# |      |                                                    |	<div class="vector-dropdown-content">              |
# |      |                                                    |                                                    |
# |      |                                                    |                                                    |
# |      |                                                    |									<div id="vector-page-tools-unpinned-co...  |
# |      |                                                    |						                                              |
# |      |                                                    |<div id="vector-page-tools" class="vector-page-...  |
# |      |                                                    |	<div                                               |
# |      |                                                    |	class="vector-pinnable-header vector-page-tool...  |
# |      |                                                    |	data-feature-name="page-tools-pinned"              |
# |      |                                                    |	data-pinnable-element-id="vector-page-tools"       |
# |      |                                                    |	data-pinned-container-id="vector-page-tools-pi...  |
# |      |                                                    |	data-unpinned-container-id="vector-page-tools-...  |
# ...
# |      |                                                    |<li><a href="/wiki/Semiconductor_memory" title=...  |
# |      |                                                    |<ul><li><a href="/wiki/Shared_memory" title="Sh...  |
# |      |                                                    |<li><a href="/wiki/Distributed_memory" title="D...  |
# |      |                                                    |<li><a href="/wiki/Distributed_shared_memory" t...  |
# |      |                                                    |<li><a href="/wiki/Uniform_memory_access" title...  |
# |      |                                                    |<li><a href="/wiki/Non-uniform_memory_access" t...  |
# |      |                                                    |<li><a href="/wiki/Cache-only_memory_architectu...  |
# |      |                                                    |<li><a href="/wiki/Massively_parallel" title="M...  |
# |      |                                                    |<li><a href="/wiki/Computer_cluster" title="Com...  |
# |      |                                                    |<ul><li><a href="/wiki/Beowulf_cluster" title="...  |
# |      |                                                    |<li><a href="/wiki/Grid_computing" title="Grid ...  |
# |      |                                                    |<li><a href="/wiki/Hardware_acceleration" title...  |
# |      |                                                    |</div></td></tr><tr><th scope="row" class="navb...  |
# |      |                                                    |<ul><li><a href="/wiki/Ateji_PX" title="Ateji P...  |
# |      |                                                    |<li><a href="/wiki/Boost_(C%2B%2B_libraries)" t...  |
# |      |                                                    |<li><a href="/wiki/Chapel_(programming_language...  |
# |      |                                                    |<li><a href="/wiki/HPX" title="HPX">HPX</a></li>    |
# |      |                                                    |<li><a href="/wiki/Charm%2B%2B" title="Charm++"...  |
# |      |                                                    |<li><a href="/wiki/Cilk" title="Cilk">Cilk</a><...  |
# |      |                                                    |<li><a href="/wiki/Coarray_Fortran" title="Coar...  |
# |      |                                                    |<li><a href="/wiki/CUDA" title="CUDA">CUDA</a><...  |
# |      |                                                    |<li><a href="/wiki/Dryad_(programming)" title="...  |
# |      |                                                    |<li><a href="/wiki/C%2B%2B_AMP" title="C++ AMP"...  |
# |      |                                                    |<li><a href="/wiki/Global_Arrays" title="Global...  |
# |      |                                                    |<li><a href="/wiki/GPUOpen" title="GPUOpen">GPU...  |
# |      |                                                    |<li><a href="/wiki/Message_Passing_Interface" t...  |
# |      |                                                    |<li><a href="/wiki/OpenMP" title="OpenMP">OpenM...  |
# |      |                                                    |<li><a href="/wiki/OpenCL" title="OpenCL">OpenC...  |
# |      |                                                    |<li><a href="/wiki/OpenHMPP" title="OpenHMPP">O...  |
# |      |                                                    |<li><a href="/wiki/OpenACC" title="OpenACC">Ope...  |
# |      |                                                    |<li><a href="/wiki/Parallel_Extensions" title="...  |
# |      |                                                    |<li><a href="/wiki/Parallel_Virtual_Machine" ti...  |
# |      |                                                    |<li><a href="/wiki/Pthreads" title="Pthreads">p...  |
# |      |                                                    |<li><a href="/wiki/RaftLib" title="RaftLib">Raf...  |
# |      |                                                    |<li><a href="/wiki/ROCm" title="ROCm">ROCm</a><...  |
# |      |                                                    |<li><a href="/wiki/Unified_Parallel_C" title="U...  |
# |      |                                                    |<li><a href="/wiki/Threading_Building_Blocks" t...  |
# |      |                                                    |<li><a href="/wiki/ZPL_(programming_language)" ...  |
# |      |                                                    |</div></td></tr><tr><th scope="row" class="navb...  |
# |      |                                                    |<ul><li><a href="/wiki/Automatic_parallelizatio...  |
# |      |                                                    |<li><a href="/wiki/Deadlock" title="Deadlock">D...  |
# |      |                                                    |<li><a href="/wiki/Deterministic_algorithm" tit...  |
# |      |                                                    |<li><a href="/wiki/Embarrassingly_parallel" tit...  |
# |      |                                                    |<li><a href="/wiki/Parallel_slowdown" title="Pa...  |
# |      |                                                    |<li><a href="/wiki/Race_condition" title="Race ...  |
# |      |                                                    |<li><a href="/wiki/Software_lockout" title="Sof...  |
# |      |                                                    |<li><a href="/wiki/Scalability" title="Scalabil...  |
# |      |                                                    |<li><a href="/wiki/Starvation_(computer_science...  |
# |      |                                                    |</div></td></tr><tr><td class="navbox-abovebelo...  |
# |      |                                                    |<ul><li><span class="noviewer" typeof="mw:File"...  |
# |      |                                                    |</div></td></tr></tbody></table></div>              |
# |      |                                                    |<!--                                                |
# |      |                                                    |NewPP limit report                                  |
# |      |                                                    |Parsed by mw1471                                    |
# |      |                                                    |Cached time: 20230904113338                         |
# |      |                                                    |Cache expiry: 1814400                               |
# |      |                                                    |Reduced expiry: false                               |
# |      |                                                    |Complications: [vary‐revision‐sha1, show‐toc]       |
# |      |                                                    |CPU time usage: 0.595 seconds                       |
# |      |                                                    |Real time usage: 0.733 seconds                      |
# |      |                                                    |Preprocessor visited node count: 5670/1000000       |
# |      |                                                    |Post‐expand include size: 145995/2097152 bytes      |
# |      |                                                    |Template argument size: 5869/2097152 bytes          |
# |      |                                                    |Highest expansion depth: 27/100                     |
# |      |                                                    |Expensive parser function count: 5/500              |
# |      |                                                    |Unstrip recursion depth: 1/20                       |
# |      |                                                    |Unstrip post‐expand size: 142150/5000000 bytes      |
# |      |                                                    |Lua time usage: 0.326/10.000 seconds                |
# |      |                                                    |Lua memory usage: 10569193/52428800 bytes           |
# |      |                                                    |Number of Wikibase entities loaded: 1/400           |
# |      |                                                    |-->                                                 |
# |      |                                                    |<!--                                                |
# |      |                                                    |Transclusion expansion time report (%,ms,calls,...  |
# |      |                                                    |100.00%  613.225      1 -total                      |
# |      |                                                    | 46.34%  284.179      2 Template:Reflist            |
# |      |                                                    | 26.46%  162.272     30 Template:Cite_web           |
# |      |                                                    | 24.60%  150.880      2 Template:Infobox            |
# |      |                                                    | 21.68%  132.918      1 Template:Infobox_software   |
# |      |                                                    | 11.99%   73.539      2 Template:Navbox             |
# |      |                                                    | 11.30%   69.308      1 Template:Apache_Softwar...  |
# |      |                                                    |  7.89%   48.368      1 Template:Short_description  |
# |      |                                                    |  7.46%   45.748      1 Template:Official_URL       |
# |      |                                                    |  7.27%   44.563      2 Template:URL                |
# |      |                                                    |-->                                                 |
# |      |                                                    |                                                    |
# |      |                                                    |<!-- Saved in parser cache with key enwiki:pcac...  |
# |      |                                                    | -->                                                |
# |      |                                                    |</div><!--esi <esi:include src="/esitest-fa8a49...  |
# |      |                                                    |<div class="printfooter" data-nosnippet="">Retr...  |
# |      |                                                    |					<div id="catlinks" class="catlinks" data-m...  |
# |      |                                                    |				</div>                                          |
# |      |                                                    |			</main>                                          |
# |      |                                                    |			                                                 |
# |      |                                                    |		</div>                                            |
# |      |                                                    |		<div class="mw-footer-container">                 |
# |      |                                                    |			                                                 |
# |      |                                                    |<footer id="footer" class="mw-footer" role="con...  |
# |      |                                                    |	<ul id="footer-info">                              |
# |      |                                                    |	<li id="footer-info-lastmod"> This page was la...  |
# |      |                                                    |	<li id="footer-info-copyright">Text is availab...  |
# |      |                                                    |additional terms may apply.  By using this site...  |
# |      |                                                    |</ul>                                               |
# |      |                                                    |                                                    |
# |      |                                                    |	<ul id="footer-places">                            |
# |      |                                                    |	<li id="footer-places-privacy"><a href="https:...  |
# |      |                                                    |	<li id="footer-places-about"><a href="/wiki/Wi...  |
# |      |                                                    |	<li id="footer-places-disclaimers"><a href="/w...  |
# |      |                                                    |	<li id="footer-places-contact"><a href="//en.w...  |
# |      |                                                    |	<li id="footer-places-wm-codeofconduct"><a hre...  |
# |      |                                                    |	<li id="footer-places-mobileview"><a href="//e...  |
# |      |                                                    |	<li id="footer-places-developers"><a href="htt...  |
# |      |                                                    |	<li id="footer-places-statslink"><a href="http...  |
# |      |                                                    |	<li id="footer-places-cookiestatement"><a href...  |
# |      |                                                    |</ul>                                               |
# |      |                                                    |                                                    |
# |      |                                                    |	<ul id="footer-icons" class="noprint">             |
# |      |                                                    |	<li id="footer-copyrightico"><a href="https://...  |
# |      |                                                    |	<li id="footer-poweredbyico"><a href="https://...  |
# |      |                                                    |</ul>                                               |
# |      |                                                    |                                                    |
# |      |                                                    |</footer>                                           |
# |      |                                                    |                                                    |
# |      |                                                    |		</div>                                            |
# |      |                                                    |	</div>                                             |
# |      |                                                    |</div>                                              |
# |      |                                                    |<div class="vector-settings" id="p-dock-bottom">    |
# |      |                                                    |	<ul>                                               |
# |      |                                                    |		<li><button class="cdx-button cdx-button--ico...  |
# |      |                                                    |                                                    |
# |      |                                                    |<span>Toggle limited content width</span>           |
# |      |                                                    |</button>                                           |
# |      |                                                    |</li>                                               |
# |      |                                                    |	</ul>                                              |
# |      |                                                    |</div>                                              |
# |      |                                                    |<script>(RLQ=window.RLQ||[]).push(function(){mw...  |
# |      |                                                    |<script type="application/ld+json">{"@context":...  |
# |      |                                                    |</body>                                             |
# |      |                                                    |</html>                                             |
# ------------------------------------------------------------------------------------------------------------------

# %%
# TODO: Create a pandas dataframe called `backtopandas` from the Snowpark dataframe you just created
backtopandas = spDataFrame.toPandas()
# TODO: Show the pandas data frame, just to be sure
backtopandas
# Out:
#    ID                                            WEBSITE  \
# 0   1        https://en.wikipedia.org/wiki/Snowflake_Inc
# 1   2  https://en.wikipedia.org/wiki/Amazon_Web_Services
# 2   3  https://en.wikipedia.org/wiki/Google_Cloud_Pla...
# 3   4      https://en.wikipedia.org/wiki/Microsoft_Azure
# 4   5         https://en.wikipedia.org/wiki/Apache_Spark
#
#                                                 HTML
# 0  b'<!DOCTYPE html>\n<html class="client-nojs ve...
# 1  b'<!DOCTYPE html>\n<html class="client-nojs ve...
# 2  b'<!DOCTYPE html>\n<html class="client-nojs ve...
# 3  b'<!DOCTYPE html>\n<html class="client-nojs ve...
# 4  b'<!DOCTYPE html>\n<html class="client-nojs ve...

# %% [markdown]
# ## UDF

# %% [markdown]
# Testing

# %%
# Function to get rid of HTML tags in a HTML string and remove groups of new lines when they are bundled together
def clean_html_dev(html):
    clean = BeautifulSoup(html, 'lxml').text
    clean = re.sub(r'\n+','\n', clean)
    return clean

# %%
# Extract some sample HTML from the pandas dataframe
test_html = backtopandas.loc[0,'HTML']
# Print the result to check everything is working
print(clean_html_dev(test_html))
# Out:
# Snowflake Inc. - Wikipedia
# Jump to content
# Main menu
# Main menu
# move to sidebar
# hide
# 		Navigation
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
# 		Contribute
#
# HelpLearn to editCommunity portalRecent changesUpload file
# Languages
# Language links are at the top of the page across from the title.
# Search
# Search
# Create accountLog in
# Personal tools
#  Create account Log in
# 		Pages for logged out editors learn more
# ContributionsTalk
# Contents
# move to sidebar
# hide
# (Top)
# 1History
# 2References
# 3External links
# Toggle the table of contents
# Toggle the table of contents
# Snowflake Inc.
# 7 languages
# DeutschEspañolفارسیFrançaisעבריתNorsk bokmålSvenska
# Edit links
# ArticleTalk
# English
# ReadEditView history
# Tools
# Tools
# move to sidebar
# hide
# 		Actions
#
# ReadEditView history
# 		General
#
# What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageWikidata item
# 		Print/export
#
# Download as PDFPrintable version
# 		In other projects
#
# Wikimedia Commons
# From Wikipedia, the free encyclopedia
# (Redirected from Snowflake Inc)
# Cloud-based data-warehousing company
# Snowflake Inc.TypePublic companyTraded asNYSE: SNOW (Class A)Russell 1000 componentFoundedJuly 23, 2012; 11 years ago (2012-07-23)FoundersBenoît DagevilleThierry CruanesMarcin ŻukowskiHeadquartersBozeman, Montana, U.S.Key peopleFrank Slootman, Chairperson & CEOBenoît Dageville, PresidentThierry Cruanes, CTOServicesCloud Data PlatformRevenue US$2.067 billion (2023)Operating income US$−842 million (2023)Net income US$−797 million (2023)Total assets US$7.722 billion (2023)Total equity US$5.456 billion (2023)Number of employees5,884 (2023)Websitewww.snowflake.com Footnotes / referencesFinancials as of January 31, 2023[update][1]
# Snowflake Inc. is a cloud computing–based data cloud company based in Bozeman, Montana. It was founded in July 2012 and was publicly launched in October 2014 after two years in stealth mode.[2][3]
# The firm offers a cloud-based data storage and analytics service, generally termed "data-as-a-service".[4][5] It allows corporate users to store and analyze data using cloud-based hardware and software. Snowflake services main features are separation of storage and compute, on-the-fly scalable compute, data sharing, data cloning, and third-party tools support in order to scale with its enterprise customers.[6] It runs on Amazon S3 since 2014,[2] on Microsoft Azure since 2018[7] and on the Google Cloud Platform since 2019.[8][9] The company was ranked first on the Forbes Cloud 100 in 2019.[10] The company's initial public offering raised $3.4 billion in September 2020, one of the largest software IPOs in history.[11]
# History[edit]
# Snowflake booth
# Snowflake Inc. was founded in July 2012 in San Mateo, California by three data warehousing experts: Benoît Dageville, Thierry Cruanes and Marcin Żukowski. Dageville and Cruanes previously worked as data architects at Oracle Corporation; Żukowski was a co-founder of the Dutch start-up Vectorwise. The company's first CEO was Mike Speiser, a venture capitalist at Sutter Hill Ventures.[12]
# In June 2014, the company appointed former Microsoft executive Bob Muglia as CEO. In October 2014, it raised $26 million and came out of stealth mode, being used by 80 organizations.[13]  In June 2015, the company raised an additional $45 million and launched its first product, its cloud data warehouse, to the public.[14][15][16] It raised another  $100 million in April 2017.[17][18] In January 2018, the company announced a $263 million financing round at a $1.5 billion valuation, making it a unicorn.[19] In October 2018, it raised another $450 million in a round led by Sequoia Capital, raising its valuation to $3.5 billion.[4][20]
# In May 2019, Frank Slootman, the retired former CEO of ServiceNow, joined Snowflake as its CEO and Michael Scarpelli, the former CFO of ServiceNow joined the company as CFO.[8] In June 2019, the company launched Snowflake Data Exchange.[21] In September 2019, it was ranked first on LinkedIn's 2019 U.S. list of Top Startups.[22]
# On February 7, 2020, the company raised another $479 million. At that time, it had 3,400 active customers.[23] On September 16, 2020, Snowflake became a public company via an initial public offering (IPO) raising $3.4 billion, one of the largest software IPOs and the largest to double on its first day of trading.[11][24][25][26][27]
# On May 26, 2021, the company announced that it would become headquarterless,[28] with a principal executive office located in Bozeman, Montana.[29]
# On March 2, 2022, the company acquired Streamlit for $800 million. [30] Then on October 17, 2022, the company announced an investment in advanced TV advertising firm OpenAP.[31]
# Snowflake announced it would acquire privacy-focused search startup Neeva in May 2023.[32]
# References[edit]
# ^ "US SEC: Form 10-K Snowflake, Inc". U.S. Securities and Exchange Commission. March 29, 2023.
# ^ a b Handy, Alex (October 23, 2014). "Snowflake offers cloud data warehouse as a service, cheaply". SD Times.
# ^ Wingfield, Nick (October 21, 2014). "Longtime Microsoft Executive Opens Cloud Database Start-Up". The New York Times. Retrieved June 6, 2023.
# ^ a b Dignan, Larry (October 22, 2018). "Snowflake raises $450 million in another VC round, valued at $3.5 billion". ZDNet.
# ^ Bass, Dina (October 21, 2014). "Snowflake Takes Aim at Amazon, Hadoop With New Data Service". Bloomberg News.
# ^ Reckers, Ed (January 14, 2022). "What is the Snowflake Data Platform?". SnapLogic. Retrieved October 22, 2022.
# ^ Brust, Andrew (July 12, 2018). "Snowflake's cloud data warehouse comes to Microsoft Azure". ZDNet.
# ^ a b Taulli, Tom (June 5, 2019). "Snowflake: The AI Force Multiplier". Forbes.
# ^ Ichhpurani, Kevin (June 4, 2019). "Announcing Snowflake on Google Cloud Platform". Google Cloud Platform.
# ^ Brier, Elisabeth; Cai, Kenrick; Jeans, David; Melton, Monica (September 16, 2020). Konrad, Alex (ed.). "The Cloud 100 2019". Forbes.
# ^ a b La Monica, Paul R. (September 16, 2020). "Snowflake Shares More than Double. It's the Biggest Software IPO Ever". CNN. New York. Retrieved June 6, 2023.
# ^ Anders, George (September 4, 2019). "You're never too old to excel: How Snowflake thrives with 'dinosaur' cofounders and a 60-year-old CEO". LinkedIn.
# ^ Vanian, Jonathan (October 21, 2014). "With $26M, Snowflake Computing is hoping its take on data warehousing will hit the mainstream". Gigaom.
# ^ Vanian, Jonathan (June 23, 2015). "This big data startup is as unique as a snowflake". Fortune.
# ^ Hesseldahl, Arik (June 23, 2015). "Big Data Startup Snowflake Raises $45 Million, Launches First Product". Vox Media.
# ^ Brust, Andrew (June 26, 2015). "Cloud data warehouse race heats up". ZDNet.
# ^ Dignan, Larry (April 5, 2017). "Snowflake Computing raises $100 million to expand cloud data warehouse footprint". ZDNet.
# ^ Magistretti, Bérénice; Novet, Jordan (April 5, 2017). "Cloud data warehouse startup Snowflake raises $100 million led by Iconiq". VentureBeat.
# ^ Miller, Ron (January 25, 2018). "Snowflake lands massive $263 million investment on unicorn valuation". TechCrunch.
# ^ Krazit, Tom (October 11, 2018). "With huge new $450M funding round, Snowflake Computing has now raised almost $1 billion". GeekWire.
# ^ "Snowflake Announces Data Exchange to Break Down Data Barriers" (Press release). PR Newswire. Snowflake Inc. June 4, 2019.
# ^ Hempel, Jessi (September 4, 2019). "LinkedIn Top Startups 2019: The 50 hottest U.S. companies to work for now". LinkedIn.
# ^ Miller, Ron (February 9, 2020). "After $479M round on $12.4B valuation, Snowflake CEO says IPO is next step". TechCrunch.
# ^ Driebusch, Corrie (September 16, 2020). "Snowflake's Stock Price Soars in IPO". The Wall Street Journal.
# ^ Bary, Emily (September 16, 2020). "Snowflake IPO surge makes it the priciest tech stock by a mile". MarketWatch.
# ^ Zara, Christopher (September 16, 2020). "Snowflake, JFrog IPO: Software stocks soar in market debut". Fast Company.
# ^ Pressman, Aaron (September 16, 2020). "Snowflake CEO: Doubling of stock price after IPO reflects 'frothy' market". Fortune.
# ^ Levy, Ari (May 26, 2021). "Snowflake relocates executive office from California to Bozeman, Montana, as company goes distributed". CNBC. Retrieved March 3, 2022.
# ^ "Snowflake Reports Financial Results for the First Quarter of Fiscal 2022" (Press release). Snowflake Inc. May 26, 2021.
# ^ Miller, Ron (March 2, 2022). "Snowflake acquires Streamlit for $800M to help customers build data-based apps". TechCrunch. Retrieved July 24, 2023.
# ^ Sharma, Shubham (October 17, 2022). "Snowflake acquires stake in OpenAP to set up data clean room for advertisers". VentureBeat. Retrieved October 19, 2022.
# ^ Palmer, Annie (May 24, 2023). "Snowflake shares plunge 12% on guidance miss, acquisition of search startup Neeva". CNBC.
# External links[edit]
# Wikimedia Commons has media related to Snowflake Inc..
# Official website
# Business data for Snowflake Inc.: BloombergGoogleReutersSEC filingsYahoo!
# Retrieved from "https://en.wikipedia.org/w/index.php?title=Snowflake_Inc.&oldid=1172041216"
# Categories: 2012 establishments in California2020 initial public offeringsAmerican companies established in 2012Big data companiesBig data productsData warehousing productsCloud databasesCloud computing providersInformation technology companies of the United StatesComputer companies established in 2012Companies listed on the New York Stock ExchangeHidden categories: Pages with non-numeric formatnum argumentsArticles with short descriptionShort description is different from WikidataUse American English from June 2023All Wikipedia articles written in American EnglishUse mdy dates from June 2023Articles containing potentially dated statements from January 2023All articles containing potentially dated statementsCommons category link from Wikidata
#  This page was last edited on 24 August 2023, at 15:33 (UTC).
# Text is available under the Creative Commons Attribution-ShareAlike License 4.0;
# additional terms may apply.  By using this site, you agree to the Terms of Use and Privacy Policy. Wikipedia® is a registered trademark of the Wikimedia Foundation, Inc., a non-profit organization.
# Privacy policy
# About Wikipedia
# Disclaimers
# Contact Wikipedia
# Code of Conduct
# Mobile view
# Developers
# Statistics
# Cookie statement
# Toggle limited content width

# %% [markdown]
# ## Developing

# %%
# TODO: Register a UDF with Snowpark based on the `clean_html_dev` function above
@udf(return_type=StringType(), input_types=[StringType()], name="clean_html",
     packages =["BeautifulSoup4","lxml"], replace=True)
def clean_html(html):
    clean = BeautifulSoup(html, 'lxml').text
    clean = re.sub(r'\n+','\n', clean)
    return clean
# Out:
# The version of package 'lxml' in the local environment is 4.9.3, which does not fit the criteria for the requirement 'lxml'. Your UDF might not work when the package version is different between the server and your local environment.

# %%
# Create a new column that applies the UDF to the `HTML`` column called `website_text`, and then drop `HTML`
ndf = spDataFrame.withColumn(
    "website_text",
    clean_html("html")
).drop("html")

# %%
# Show the resulting data frame to check it works
ndf.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------
# |"ID"  |"WEBSITE"                                           |"WEBSITE_TEXT"                                      |
# ------------------------------------------------------------------------------------------------------------------
# |1     |https://en.wikipedia.org/wiki/Snowflake_Inc         |                                                    |
# |      |                                                    |Snowflake Inc. - Wikipedia                          |
# |      |                                                    |Jump to content                                     |
# |      |                                                    |Main menu                                           |
# |      |                                                    |Main menu                                           |
# |      |                                                    |move to sidebar                                     |
# |      |                                                    |hide                                                |
# |      |                                                    |		Navigation                                        |
# |      |                                                    |	                                                   |
# |      |                                                    |Main pageContentsCurrent eventsRandom articleAb...  |
# |      |                                                    |		Contribute                                        |
# |      |                                                    |	                                                   |
# |      |                                                    |HelpLearn to editCommunity portalRecent changes...  |
# |      |                                                    |Languages                                           |
# |      |                                                    |Language links are at the top of the page acros...  |
# |      |                                                    |Search                                              |
# |      |                                                    |Search                                              |
# |      |                                                    |Create accountLog in                                |
# |      |                                                    |Personal tools                                      |
# |      |                                                    | Create account Log in                              |
# |      |                                                    |		Pages for logged out editors learn more           |
# |      |                                                    |ContributionsTalk                                   |
# |      |                                                    |Contents                                            |
# |      |                                                    |move to sidebar                                     |
# |      |                                                    |hide                                                |
# |      |                                                    |(Top)                                               |
# |      |                                                    |1History                                            |
# |      |                                                    |2References                                         |
# |      |                                                    |3External links                                     |
# |      |                                                    |Toggle the table of contents                        |
# |      |                                                    |Toggle the table of contents                        |
# |      |                                                    |Snowflake Inc.                                      |
# |      |                                                    |7 languages                                         |
# |      |                                                    |DeutschEspañolفارسیFrançaisעבריתNorsk bokmålSve...  |
# |      |                                                    |Edit links                                          |
# |      |                                                    |ArticleTalk                                         |
# |      |                                                    |English                                             |
# |      |                                                    |ReadEditView history                                |
# |      |                                                    |Tools                                               |
# |      |                                                    |Tools                                               |
# |      |                                                    |move to sidebar                                     |
# |      |                                                    |hide                                                |
# |      |                                                    |		Actions                                           |
# |      |                                                    |	                                                   |
# |      |                                                    |ReadEditView history                                |
# |      |                                                    |		General                                           |
# |      |                                                    |	                                                   |
# |      |                                                    |What links hereRelated changesUpload fileSpecia...  |
# |      |                                                    |		Print/export                                      |
# |      |                                                    |	                                                   |
# |      |                                                    |Download as PDFPrintable version                    |
# |      |                                                    |		In other projects                                 |
# |      |                                                    |	                                                   |
# |      |                                                    |Wikimedia Commons                                   |
# |      |                                                    |From Wikipedia, the free encyclopedia               |
# |      |                                                    |(Redirected from Snowflake Inc)                     |
# |      |                                                    |Cloud-based data-warehousing company                |
# |      |                                                    |Snowflake Inc.TypePublic companyTraded asNYSE: ...  |
# |      |                                                    |Snowflake Inc. is a cloud computing–based data ...  |
# |      |                                                    |The firm offers a cloud-based data storage and ...  |
# |      |                                                    |History[edit]                                       |
# |      |                                                    |Snowflake booth                                     |
# |      |                                                    |Snowflake Inc. was founded in July 2012 in San ...  |
# |      |                                                    |In June 2014, the company appointed former Micr...  |
# |      |                                                    |In May 2019, Frank Slootman, the retired former...  |
# |      |                                                    |On February 7, 2020, the company raised another...  |
# |      |                                                    |On May 26, 2021, the company announced that it ...  |
# |      |                                                    |On March 2, 2022, the company acquired Streamli...  |
# |      |                                                    |Snowflake announced it would acquire privacy-fo...  |
# |      |                                                    |References[edit]                                    |
# |      |                                                    |^ "US SEC: Form 10-K Snowflake, Inc". U.S. Secu...  |
# |      |                                                    |^ a b Handy, Alex (October 23, 2014). "Snowflak...  |
# |      |                                                    |^ Wingfield, Nick (October 21, 2014). "Longtime...  |
# |      |                                                    |^ a b Dignan, Larry (October 22, 2018). "Snowfl...  |
# |      |                                                    |^ Bass, Dina (October 21, 2014). "Snowflake Tak...  |
# |      |                                                    |^ Reckers, Ed (January 14, 2022). "What is the ...  |
# |      |                                                    |^ Brust, Andrew (July 12, 2018). "Snowflake's c...  |
# |      |                                                    |^ a b Taulli, Tom (June 5, 2019). "Snowflake: T...  |
# |      |                                                    |^ Ichhpurani, Kevin (June 4, 2019). "Announcing...  |
# |      |                                                    |^ Brier, Elisabeth; Cai, Kenrick; Jeans, David;...  |
# |      |                                                    |^ a b La Monica, Paul R. (September 16, 2020). ...  |
# |      |                                                    |^ Anders, George (September 4, 2019). "You're n...  |
# |      |                                                    |^ Vanian, Jonathan (October 21, 2014). "With $2...  |
# |      |                                                    |^ Vanian, Jonathan (June 23, 2015). "This big d...  |
# |      |                                                    |^ Hesseldahl, Arik (June 23, 2015). "Big Data S...  |
# |      |                                                    |^ Brust, Andrew (June 26, 2015). "Cloud data wa...  |
# |      |                                                    |^ Dignan, Larry (April 5, 2017). "Snowflake Com...  |
# |      |                                                    |^ Magistretti, Bérénice; Novet, Jordan (April 5...  |
# |      |                                                    |^ Miller, Ron (January 25, 2018). "Snowflake la...  |
# |      |                                                    |^ Krazit, Tom (October 11, 2018). "With huge ne...  |
# |      |                                                    |^ "Snowflake Announces Data Exchange to Break D...  |
# |      |                                                    |^ Hempel, Jessi (September 4, 2019). "LinkedIn ...  |
# |      |                                                    |^ Miller, Ron (February 9, 2020). "After $479M ...  |
# |      |                                                    |^ Driebusch, Corrie (September 16, 2020). "Snow...  |
# |      |                                                    |^ Bary, Emily (September 16, 2020). "Snowflake ...  |
# |      |                                                    |^ Zara, Christopher (September 16, 2020). "Snow...  |
# |      |                                                    |^ Pressman, Aaron (September 16, 2020). "Snowfl...  |
# |      |                                                    |^ Levy, Ari (May 26, 2021). "Snowflake relocate...  |
# |      |                                                    |^ "Snowflake Reports Financial Results for the ...  |
# |      |                                                    |^ Miller, Ron (March 2, 2022). "Snowflake acqui...  |
# |      |                                                    |^ Sharma, Shubham (October 17, 2022). "Snowflak...  |
# |      |                                                    |^ Palmer, Annie (May 24, 2023). "Snowflake shar...  |
# |      |                                                    |External links[edit]                                |
# |      |                                                    |Wikimedia Commons has media related to Snowflak...  |
# |      |                                                    |Official website                                    |
# |      |                                                    |Business data for Snowflake Inc.: BloombergGoog...  |
# |      |                                                    |Retrieved from "https://en.wikipedia.org/w/inde...  |
# |      |                                                    |Categories: 2012 establishments in California20...  |
# |      |                                                    | This page was last edited on 24 August 2023, a...  |
# |      |                                                    |Text is available under the Creative Commons At...  |
# |      |                                                    |additional terms may apply.  By using this site...  |
# |      |                                                    |Privacy policy                                      |
# |      |                                                    |About Wikipedia                                     |
# |      |                                                    |Disclaimers                                         |
# |      |                                                    |Contact Wikipedia                                   |
# |      |                                                    |Code of Conduct                                     |
# |      |                                                    |Mobile view                                         |
# |      |                                                    |Developers                                          |
# |      |                                                    |Statistics                                          |
# |      |                                                    |Cookie statement                                    |
# |      |                                                    |Toggle limited content width                        |
# |      |                                                    |                                                    |
# |2     |https://en.wikipedia.org/wiki/Amazon_Web_Services   |                                                    |
# |      |                                                    |Amazon Web Services - Wikipedia                     |
# |      |                                                    |Jump to content                                     |
# |      |                                                    |Main menu                                           |
# |      |                                                    |Main menu                                           |
# |      |                                                    |move to sidebar                                     |
# |      |                                                    |hide                                                |
# |      |                                                    |		Navigation                                        |
# |      |                                                    |	                                                   |
# |      |                                                    |Main pageContentsCurrent eventsRandom articleAb...  |
# |      |                                                    |		Contribute                                        |
# |      |                                                    |	                                                   |
# |      |                                                    |HelpLearn to editCommunity portalRecent changes...  |
# |      |                                                    |Languages                                           |
# |      |                                                    |Language links are at the top of the page acros...  |
# |      |                                                    |Search                                              |
# |      |                                                    |Search                                              |
# |      |                                                    |Create accountLog in                                |
# |      |                                                    |Personal tools                                      |
# |      |                                                    | Create account Log in                              |
# |      |                                                    |		Pages for logged out editors learn more           |
# |      |                                                    |ContributionsTalk                                   |
# |      |                                                    |Contents                                            |
# |      |                                                    |move to sidebar                                     |
# |      |                                                    |hide                                                |
# |      |                                                    |(Top)                                               |
# |      |                                                    |1Services                                           |
# |      |                                                    |2History                                            |
# |      |                                                    |Toggle History subsection                           |
# |      |                                                    |2.1Founding (2000–2005)                             |
# |      |                                                    |2.2S3, EC2, and other first generation services...  |
# |      |                                                    |2.3Growth (2010–2015)                               |
# |      |                                                    |2.4Market leadership (2016–present)                 |
# |      |                                                    |2.5Customer base                                    |
# |      |                                                    |2.6Significant service outages                      |
# |      |                                                    |3Availability and topology                          |
# |      |                                                    |4Pop-up lofts                                       |
# |      |                                                    |5Charitable work                                    |
# |      |                                                    |6Environmental impact                               |
# |      |                                                    |7Denaturalization protest                           |
# |      |                                                    |8See also                                           |
# |      |                                                    |9Notes                                              |
# |      |                                                    |10References                                        |
# |      |                                                    |11External links                                    |
# |      |                                                    |Toggle the table of contents                        |
# |      |                                                    |Toggle the table of contents                        |
# |      |                                                    |Amazon Web Services                                 |
# |      |                                                    |39 languages                                        |
# |      |                                                    |العربيةAzərbaycancaবাংলাБългарскиCatalàČeštinaD...  |
# |      |                                                    |Edit links                                          |
# |      |                                                    |ArticleTalk                                         |
# |      |                                                    |English                                             |
# |      |                                                    |ReadEditView history                                |
# |      |                                                    |Tools                                               |
# |      |                                                    |Tools                                               |
# |      |                                                    |move to sidebar                                     |
# |      |                                                    |hide                                                |
# |      |                                                    |		Actions                                           |
# |      |                                                    |	                                                   |
# |      |                                                    |ReadEditView history                                |
# |      |                                                    |		General                                           |
# |      |                                                    |	                                                   |
# |      |                                                    |What links hereRelated changesUpload fileSpecia...  |
# |      |                                                    |		Print/export                                      |
# |      |                                                    |	                                                   |
# |      |                                                    |Download as PDFPrintable version                    |
# |      |                                                    |		In other projects                                 |
# |      |                                                    |	                                                   |
# |      |                                                    |Wikimedia Commons                                   |
# |      |                                                    |From Wikipedia, the free encyclopedia               |
# |      |                                                    |On-demand cloud computing company                   |
# |      |                                                    |"AWS" redirects here. For other uses, see AWS (...  |
# |      |                                                    |Amazon Web Services, Inc.Type of siteSubsidiary...  |
# |      |                                                    |Adam Selipsky (CEO)[1]                              |
# |      |                                                    |C.J. Moses (CISO)[2]                                |
# |      |                                                    |IndustryWeb service, cloud computingRevenue US$...  |
# |      |                                                    |Annapurna Labs                                      |
# |      |                                                    |AWS Elemental                                       |
# |      |                                                    |NICE Software[4]                                    |
# |      |                                                    |Wickr                                               |
# |      |                                                    |URLaws.amazon.comLaunched                           |
# |      |                                                    |Web services: July 2002; 21 years ago (2002-07)[a]  |
# |      |                                                    |Cloud computing: March 2006; 17 years ago (2006...  |
# |      |                                                    |Current statusActive                                |
# |      |                                                    |Amazon Web Services, Inc. (AWS) is a subsidiary...  |
# |      |                                                    |One of the foundational services is Amazon Elas...  |
# |      |                                                    |AWS services are delivered to customers via a n...  |
# |      |                                                    |Amazon markets AWS to subscribers as a way of o...  |
# |      |                                                    |Services[edit]                                      |
# |      |                                                    |Main articles: Amazon Elastic Compute Cloud and...  |
# |      |                                                    |As of 2021, AWS comprises over 200[12] products...  |
# |      |                                                    |Services expose functionality through APIs for ...  |
# |      |                                                    |History[edit]                                       |
# |      |                                                    |Further information: Timeline of Amazon Web Ser...  |
# |      |                                                    |Founding (2000–2005)[edit]                          |
# |      |                                                    |Early AWS "building blocks" logo along a sigmoi...  |
# |      |                                                    |The genesis of AWS came in the early 2000s. Aft...  |
# |      |                                                    |Around the same time frame, Amazon was frustrat...  |
# |      |                                                    |In July 2002, Amazon.com Web Services, managed ...  |
# |      |                                                    |By the Summer of 2003, Andy Jassy had taken ove...  |
# |      |                                                    |Jeff Barr, an early AWS employee, credits Verme...  |
# |      |                                                    |Jassy assembled a founding team of 57 employees...  |
# |      |                                                    |In late 2003, the concept for compute,[e] which...  |
# |      |                                                    |In November 2004, AWS launched its first infras...  |
# |      |                                                    |S3, EC2, and other first generation services (2...  |
# |      |                                                    |This section is missing information about Simpl...  |
# |      |                                                    |On March 14, 2006, AWS launched Amazon S3 cloud...  |
# |      |                                                    |In September 2007, AWS announced its annual Sta...  |
# |      |                                                    |Additional AWS services from this period includ...  |
# |      |                                                    |Growth (2010–2015)[edit]                            |
# |      |                                                    |AWS Summit 2013 event in NYC.                       |
# |      |                                                    |In November 2010, it was reported that all of A...  |
# |      |                                                    |On November 27, 2012, AWS hosted its first majo...  |
# |      |                                                    |To support industry-wide training and skills st...  |
# |      |                                                    |In 2014, AWS launched its partner network, AWS ...  |
# |      |                                                    |In January 2015, Amazon Web Services acquired A...  |
# |      |                                                    |In April 2015, Amazon.com reported AWS was prof...  |
# |      |                                                    |Market leadership (2016–present)[edit]              |
# |      |                                                    |James Hamilton, who leads AWS' compute, data ce...  |
# |      |                                                    |In 2016 Q1, revenue was $2.57 billion with net ...  |
# |      |                                                    |AWS had $17.46 billion in annual revenue in 201...  |
# |      |                                                    |In January 2018, Amazon launched an autoscaling...  |
# |      |                                                    |In November 2018, AWS announced customized ARM ...  |
# |      |                                                    |In 2019, AWS reported 37% yearly growth and acc...  |
# |      |                                                    |In April 2021, AWS reported 32% yearly growth a...  |
# |      |                                                    |In January 2022, AWS joined the MACH Alliance a...  |
# |      |                                                    |In June 2022, it was reported that in 2019 Capi...  |
# |      |                                                    |In June 2022, AWS announced they had launched t...  |
# |      |                                                    |In June 2022, Amazon announced and displayed a ...  |
# |      |                                                    |Customer base[edit]                                 |
# |      |                                                    |On March 14, 2006, Amazon said in a press relea...  |
# |      |                                                    |In November 2012, AWS hosted its first customer...  |
# |      |                                                    |On May 13, 2013, AWS was awarded an Agency Auth...  |
# |      |                                                    |In October 2013, it was revealed that AWS was a...  |
# |      |                                                    |In August 2014, AWS received Department of Defe...  |
# |      |                                                    |During the 2015 re:Invent keynote, AWS disclose...  |
# |      |                                                    |On April 5, 2017, AWS and DXC Technology (forme...  |
# |      |                                                    |Notable customers include NASA,[93] the Obama p...  |
# |      |                                                    |In 2019, it was reported that more than 80% of ...  |
# |      |                                                    |In August 2019, the U.S. Navy said it moved 72,...  |
# |      |                                                    |In 2021, DISH Network announced it will develop...  |
# |      |                                                    |In October 2021, it was reported that spy agenc...  |
# |      |                                                    |Multiple financial services firms have shifted ...  |
# |      |                                                    |Significant service outages[edit]                   |
# |      |                                                    |Main article: Timeline of Amazon Web Services §...  |
# |      |                                                    |On April 20, 2011, AWS suffered a major outage....  |
# |      |                                                    |On June 29, 2012, several websites that rely on...  |
# |      |                                                    |On October 22, 2012, a major outage occurred, a...  |
# |      |                                                    |On December 24, 2012, AWS suffered another outa...  |
# |      |                                                    |On February 28, 2017, AWS experienced a massive...  |
# |      |                                                    |On November 25, 2020, AWS experienced several h...  |
# |      |                                                    |On December 7, 2021, an outage mainly affected ...  |
# |      |                                                    |Availability and topology[edit]                     |
# |      |                                                    |As of January 2023[update], AWS has distinct op...  |
# |      |                                                    |Each region is wholly contained within a single...  |
# |      |                                                    |As of December 2014, Amazon Web Services operat...  |
# |      |                                                    |As of January 2023[update], AWS has announced t...  |
# |      |                                                    |In 2014, AWS claimed its aim was to achieve 100...  |
# |      |                                                    |Pop-up lofts[edit]                                  |
# |      |                                                    |AWS Loft in SoHo, New York City                     |
# |      |                                                    |AWS also has "pop-up lofts" in different locati...  |
# |      |                                                    |Charitable work[edit]                               |
# |      |                                                    |In 2017, AWS launched AWS re/Start in the Unite...  |
# |      |                                                    |In April 2022, AWS announced the organization h...  |
# |      |                                                    |Environmental impact[edit]                          |
# |      |                                                    |In 2016, Greenpeace assessed major tech compani...  |
# |      |                                                    |In January 2021, AWS joined an industry pledge ...  |
# |      |                                                    |Denaturalization protest[edit]                      |
# |      |                                                    |US Department of Homeland Security has employed...  |
# |      |                                                    |See also[edit]                                      |
# |      |                                                    |Main category: Amazon Web Services                  |
# |      |                                                    |Cloud-computing comparison                          |
# |      |                                                    |Comparison of file hosting services                 |
# |      |                                                    |Tim Bray                                            |
# |      |                                                    |James Gosling                                       |
# |      |                                                    |Notes[edit]                                         |
# |      |                                                    |^ Launched in July 2002, the Amazon Web Service...  |
# |      |                                                    |^ In 2006, Amazon Web Services (AWS) began offe...  |
# |      |                                                    |^ A team shouldn't be any bigger than could be ...  |
# |      |                                                    |^ Larger software applications broken down in t...  |
# |      |                                                    |^ code-named Amazon Execution Service in the pr...  |
# |      |                                                    |References[edit]                                    |
# |      |                                                    |^ "AWS announces next CEO". aboutamazon.com (Pr...  |
# |      |                                                    |^ Haranas, Mark (August 1, 2022). "AWS CISO On ...  |
# |      |                                                    |^ a b Sharwood, Simon (April 26, 2023). "Google...  |
# |      |                                                    |^ "NICE - an AWS Company". nice-software.com. A...  |
# |      |                                                    |^ a b c "Amazon - Press Room - Press Release". ...  |
# |      |                                                    |^ "About AWS". September 2011. Archived from th...  |
# |      |                                                    |^ a b "AWS Customer Agreement". Amazon Web Serv...  |
# |      |                                                    |^ a b c "AWS Global Infrastructure". December 2...  |
# |      |                                                    |^ "What is Cloud Computing by Amazon Web Servic...  |
# |      |                                                    |^ Panettieri, Joe (August 3, 2020). "Cloud Mark...  |
# |      |                                                    |^ "Infographic: Amazon Leads $100 Billion Cloud...  |
# |      |                                                    |^ "Cloud computing with AWS". aws.amazon.com. M...  |
# |      |                                                    |^ Mosca, David (April 14, 2021). "Jersey City's...  |
# |      |                                                    |^ "Top 10 AWS Services according to popularity"...  |
# |      |                                                    |^ a b c d e "Forum for Growth & Innovation: Ove...  |
# |      |                                                    |^ a b Furrier, John (January 28, 2015). "Exclus...  |
# |      |                                                    |^ a b c d e Miller, Rob (July 2, 2016). "How AW...  |
# |      |                                                    |^ a b McLaughlin, Kevin (August 4, 2015). "Andy...  |
# |      |                                                    |^ a b c d e f g Fireside Chat with Michael Skok...  |
# |      |                                                    |^ Vogels, Werner (January 18, 2012). "Amazon Dy...  |
# |      |                                                    |^ a b c Vogels, Werner (August 28, 2019). "Mode...  |
# |      |                                                    |^ a b Stone, Brad (2013). The Everything Store:...  |
# |      |                                                    |^ Killalea, Tom (July 29, 2019). "Velocity in S...  |
# |      |                                                    |^ a b c Adam Selipsky (September 6, 2013). Amaz...  |
# |      |                                                    |^ a b Cowley, Stacy (January 21, 2004). "LinuxW...  |
# |      |                                                    |^ "Former Amazon CISO Tom Killalea Joins Carbon...  |
# |      |                                                    |^ "Colin Bryar". linkedin.com. Archived from th...  |
# |      |                                                    |^ "Amazon.com Launches Web Services; Developers...  |
# |      |                                                    |^ Cowley, Stacy (January 22, 2004). "Amazon lau...  |
# |      |                                                    |^ Bryar, Colin; Carr, Bill (2021). Working Back...  |
# |      |                                                    |^ Rushton, Katherine (December 30, 2012). "Goli...  |
# |      |                                                    |^ Barr, Jeff (November 11, 2019). "15 Years of ...  |
# |      |                                                    |^ Hern, Alex (April 24, 2018). "The two-pizza r...  |
# |      |                                                    |^ Killalea, Tom (July 29, 2019). "Velocity in S...  |
# |      |                                                    |^ Vogels, Werner (March 13, 2006). "S3 - The Am...  |
# |      |                                                    |^ "What I Learned from Jeff Bezos: How to Bring...  |
# |      |                                                    |Kahle, Brewster (August 2, 2017). "What I Learn...  |
# |      |                                                    |^ Ray, Tiernan (March 1, 2017). "Twilio CEO Law...  |
# |      |                                                    |^ Richman, Dan (August 15, 2016). "Adam Selipsk...  |
# |      |                                                    |^ Coombs, Casey (November 7, 2016). "Tableau CE...  |
# |      |                                                    |^ Gregory, Huang (October 29, 2008). "Startups ...  |
# |      |                                                    |^ Jeff, Barr (August 23, 2021). "Happy 15th Bir...  |
# |      |                                                    |^ "Benjamin Black– EC2 Origins". Blog.b3k.us. J...  |
# |      |                                                    |^ Bort, Julie (March 28, 2012). "Amazon's Game-...  |
# |      |                                                    |^ "Amazon Web Services Blog: Amazon Simple Queu...  |
# |      |                                                    |^ "Amazon Web Services Launches" (Press release...  |
# |      |                                                    |^ Barr, Jeff (August 25, 2006). "Amazon EC2 Bet...  |
# |      |                                                    |^ Gralla, Preston (December 26, 2006). "Computi...  |
# |      |                                                    |^ Kelleher, Kevin (March 15, 2007). "Amazon's N...  |
# |      |                                                    |^ Hemsoth, Nicole (April 22, 2021). "Amazon CTO...  |
# |      |                                                    |^ Barr, Jeff (September 12, 2007). "Announcing ...  |
# |      |                                                    |^ a b Vogels, Werner (December 6, 2007). "And t...  |
# |      |                                                    |^ Weinberger, Matt (March 17, 2016). "Amazon's ...  |
# |      |                                                    |^ Lashinsky, Adam (May 12, 2008). "Where does G...  |
# |      |                                                    |^ "2011 AWS Tour Australia, Closing Keynote: Ho...  |
# |      |                                                    |^ "Cloud Computing 2013: The Amazon Gorilla Inv...  |
# |      |                                                    |^ "Amazon CEO Jeff Bezos Will Address Cloud Par...  |
# |      |                                                    |^ a b Barr, Jeff (July 17, 2012). "Get Ready to...  |
# |      |                                                    |^ "AWS re:Invent - Why Attend?" (PDF). awsmedia...  |
# |      |                                                    |^ a b Crockcroft, Adrian (December 3, 2012). "A...  |
# |      |                                                    |^ Vogels, Werner (May 9, 2012). "AWS re:Invent"...  |
# |      |                                                    |^ "AWS began offering a certification program f...  |
# |      |                                                    |^ O'Dell, J (October 11, 2013). "'The first one...  |
# |      |                                                    |^ "Announcing the Launch of the AWS Partner Net...  |
# |      |                                                    |^ "EdgeIQ Orchestration for AWS". Amazon Web Se...  |
# |      |                                                    |^ "Amazon to buy Israeli start-up Annapurna Lab...  |
# |      |                                                    |^ "Amazon buys secretive chip maker Annapurna L...  |
# |      |                                                    |^ "Amazon web services 'growing fast'". BBC New...  |
# |      |                                                    |^ Get Used to Amazon Being a Profitable Company...  |
# |      |                                                    |^ "Gartner Reprint". www.gartner.com. Retrieved...  |
# |      |                                                    |^ Wagner, Mitch (May 25, 2017). "At Amazon, It'...  |
# |      |                                                    |^ "A Decade of Innovation – Perspectives".          |
# |      |                                                    |^ Amazon's earnings soar as its hardware takes ...  |
# |      |                                                    |^ Jordan, Novet (April 7, 2016). "Andy Jassy is...  |
# |      |                                                    |^ Roberts, Daniel (May 24, 2016). "Here's why A...  |
# |      |                                                    |^ Novet, Jordan (February 1, 2018). "Amazon clo...  |
# |      |                                                    |^ Furrier, John (November 30, 2020). "Exclusive...  |
# |      |                                                    |^ Balakrishnan, Anita (April 12, 2017). "AWS CE...  |
# |      |                                                    |^ Miller, Ron. "Amazon launches autoscaling ser...  |
# |      |                                                    |^ "New AWS Auto Scaling – Unified Scaling For Y...  |
# |      |                                                    |^ "AWS launches Arm-based servers for EC2". Tec...  |
# |      |                                                    |^ "AWS launches a base station for satellites a...  |
# |      |                                                    |^ Sparks, Daniel (February 6, 2020). "Amazon's ...  |
# |      |                                                    |^ Bicheno, Scott (April 30, 2021). "AWS account...  |
# |      |                                                    |^ Edwards, Roy (January 21, 2022). "AWS Joins M...  |
# |      |                                                    |^ Burnson, Robert (June 18, 2022). "Ex-Amazon C...  |
# |      |                                                    |^ Lardinois, Frederic (June 23, 2022). "AWS sen...  |
# |      |                                                    |^ Claburn, Thomas (June 23, 2022). "Now Amazon ...  |
# |      |                                                    |^ "Amazon Web Services Announces First Global C...  |
# |      |                                                    |^ "AWS was awarded an Agency Authority to Opera...  |
# |      |                                                    |^ "US court rules for Amazon.com in CIA cloud c...  |
# |      |                                                    |^ "AWS GovCloud Earns DoD CSM Level 3-5 Provisi...  |
# |      |                                                    |^ "DXC Technology Announces Expanded Alliance w...  |
# |      |                                                    |^ John Breeden II (January 4, 2013). "The tech ...  |
# |      |                                                    |^ Lohr, Steve (November 8, 2012). "The Obama Ca...  |
# |      |                                                    |^ "Netflix Case Study". Amazon Web Services, Inc.   |
# |      |                                                    |^ Benrath, Bastian (March 3, 2019). "Cloudspart...  |
# |      |                                                    |^ Hitchens, Theresa (August 23, 2019). "Navy Ta...  |
# |      |                                                    |^ Smith, Connor. "Why DISH Was the Best-Perform...  |
# |      |                                                    |^ Warrell, Helen; Fildes, Nic. "Amazon strikes ...  |
# |      |                                                    |^ "Jefferies extends relationship with AWS to e...  |
# |      |                                                    |^ "Bloomberg Adds Data License Content to AWS C...  |
# |      |                                                    |^ "Tradeweb teams up with Amazon Web Services t...  |
# |      |                                                    |^ "BBVA collaborates with Amazon Web Services a...  |
# |      |                                                    |^ "AWS battle of the titans continues as Itivit...  |
# |      |                                                    |^ "Summary of outage occurring April 20–22, 201...  |
# |      |                                                    |^ "Summary of the AWS Service Event in the US E...  |
# |      |                                                    |^ "Summary of the October 22, 2012 AWS Service ...  |
# |      |                                                    |^ Bishop, Bryan (December 24, 2012). "Netflix s...  |
# |      |                                                    |^ "Summary of the December 24, 2012 Amazon ELB ...  |
# ...
# |      |                                                    |Massively parallel                                  |
# |      |                                                    |Cloud computing                                     |
# |      |                                                    |High-performance computing                          |
# |      |                                                    |Multiprocessing                                     |
# |      |                                                    |Manycore processor                                  |
# |      |                                                    |GPGPU                                               |
# |      |                                                    |Computer network                                    |
# |      |                                                    |Systolic array                                      |
# |      |                                                    |Levels                                              |
# |      |                                                    |Bit                                                 |
# |      |                                                    |Instruction                                         |
# |      |                                                    |Thread                                              |
# |      |                                                    |Task                                                |
# |      |                                                    |Data                                                |
# |      |                                                    |Memory                                              |
# |      |                                                    |Loop                                                |
# |      |                                                    |Pipeline                                            |
# |      |                                                    |Multithreading                                      |
# |      |                                                    |Temporal                                            |
# |      |                                                    |Simultaneous (SMT)                                  |
# |      |                                                    |Speculative (SpMT)                                  |
# |      |                                                    |Preemptive                                          |
# |      |                                                    |Cooperative                                         |
# |      |                                                    |Clustered multi-thread (CMT)                        |
# |      |                                                    |Hardware scout                                      |
# |      |                                                    |Theory                                              |
# |      |                                                    |PRAM model                                          |
# |      |                                                    |PEM model                                           |
# |      |                                                    |Analysis of parallel algorithms                     |
# |      |                                                    |Amdahl's law                                        |
# |      |                                                    |Gustafson's law                                     |
# |      |                                                    |Cost efficiency                                     |
# |      |                                                    |Karp–Flatt metric                                   |
# |      |                                                    |Slowdown                                            |
# |      |                                                    |Speedup                                             |
# |      |                                                    |Elements                                            |
# |      |                                                    |Process                                             |
# |      |                                                    |Thread                                              |
# |      |                                                    |Fiber                                               |
# |      |                                                    |Instruction window                                  |
# |      |                                                    |Array                                               |
# |      |                                                    |Coordination                                        |
# |      |                                                    |Multiprocessing                                     |
# |      |                                                    |Memory coherence                                    |
# |      |                                                    |Cache coherence                                     |
# |      |                                                    |Cache invalidation                                  |
# |      |                                                    |Barrier                                             |
# |      |                                                    |Synchronization                                     |
# |      |                                                    |Application checkpointing                           |
# |      |                                                    |Programming                                         |
# |      |                                                    |Stream processing                                   |
# |      |                                                    |Dataflow programming                                |
# |      |                                                    |Models                                              |
# |      |                                                    |Implicit parallelism                                |
# |      |                                                    |Explicit parallelism                                |
# |      |                                                    |Concurrency                                         |
# |      |                                                    |Non-blocking algorithm                              |
# |      |                                                    |Hardware                                            |
# |      |                                                    |Flynn's taxonomy                                    |
# |      |                                                    |SISD                                                |
# |      |                                                    |SIMD                                                |
# |      |                                                    |Array processing (SIMT)                             |
# |      |                                                    |Pipelined processing                                |
# |      |                                                    |Associative processing                              |
# |      |                                                    |MISD                                                |
# |      |                                                    |MIMD                                                |
# |      |                                                    |Dataflow architecture                               |
# |      |                                                    |Pipelined processor                                 |
# |      |                                                    |Superscalar processor                               |
# |      |                                                    |Vector processor                                    |
# |      |                                                    |Multiprocessor                                      |
# |      |                                                    |symmetric                                           |
# |      |                                                    |asymmetric                                          |
# |      |                                                    |Memory                                              |
# |      |                                                    |shared                                              |
# |      |                                                    |distributed                                         |
# |      |                                                    |distributed shared                                  |
# |      |                                                    |UMA                                                 |
# |      |                                                    |NUMA                                                |
# |      |                                                    |COMA                                                |
# |      |                                                    |Massively parallel computer                         |
# |      |                                                    |Computer cluster                                    |
# |      |                                                    |Beowulf cluster                                     |
# |      |                                                    |Grid computer                                       |
# |      |                                                    |Hardware acceleration                               |
# |      |                                                    |APIs                                                |
# |      |                                                    |Ateji PX                                            |
# |      |                                                    |Boost                                               |
# |      |                                                    |Chapel                                              |
# |      |                                                    |HPX                                                 |
# |      |                                                    |Charm++                                             |
# |      |                                                    |Cilk                                                |
# |      |                                                    |Coarray Fortran                                     |
# |      |                                                    |CUDA                                                |
# |      |                                                    |Dryad                                               |
# |      |                                                    |C++ AMP                                             |
# |      |                                                    |Global Arrays                                       |
# |      |                                                    |GPUOpen                                             |
# |      |                                                    |MPI                                                 |
# |      |                                                    |OpenMP                                              |
# |      |                                                    |OpenCL                                              |
# |      |                                                    |OpenHMPP                                            |
# |      |                                                    |OpenACC                                             |
# |      |                                                    |Parallel Extensions                                 |
# |      |                                                    |PVM                                                 |
# |      |                                                    |pthreads                                            |
# |      |                                                    |RaftLib                                             |
# |      |                                                    |ROCm                                                |
# |      |                                                    |UPC                                                 |
# |      |                                                    |TBB                                                 |
# |      |                                                    |ZPL                                                 |
# |      |                                                    |Problems                                            |
# |      |                                                    |Automatic parallelization                           |
# |      |                                                    |Deadlock                                            |
# |      |                                                    |Deterministic algorithm                             |
# |      |                                                    |Embarrassingly parallel                             |
# |      |                                                    |Parallel slowdown                                   |
# |      |                                                    |Race condition                                      |
# |      |                                                    |Software lockout                                    |
# |      |                                                    |Scalability                                         |
# |      |                                                    |Starvation                                          |
# |      |                                                    | Category: Parallel computing                       |
# |      |                                                    |Retrieved from "https://en.wikipedia.org/w/inde...  |
# |      |                                                    |Categories: Apache Software Foundation projects...  |
# |      |                                                    | This page was last edited on 4 September 2023,...  |
# |      |                                                    |Text is available under the Creative Commons At...  |
# |      |                                                    |additional terms may apply.  By using this site...  |
# |      |                                                    |Privacy policy                                      |
# |      |                                                    |About Wikipedia                                     |
# |      |                                                    |Disclaimers                                         |
# |      |                                                    |Contact Wikipedia                                   |
# |      |                                                    |Code of Conduct                                     |
# |      |                                                    |Mobile view                                         |
# |      |                                                    |Developers                                          |
# |      |                                                    |Statistics                                          |
# |      |                                                    |Cookie statement                                    |
# |      |                                                    |Toggle limited content width                        |
# |      |                                                    |                                                    |
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Flattening

# %%
# TODO: Run the below SQL
demo_session.sql(
    """ 
    create or replace stage demo_stg
        url = 's3://frostyfridaychallenges/challenge_25/'
        file_format = (type = json);
    """
).collect()
demo_session.sql(
    """
    create or replace table demo_json as
        select $1 as data
        from @demo_stg (pattern => '.*ber_7d.*');
    """
).collect()
# Out:
# [Row(status='Table DEMO_JSON successfully created.')]

# %%
# TODO: Run the below code
json_df = demo_session.table("demo_json")

# %%
# TODO: .show() the result
json_df.show()
# Out:
# ------------------------------------------------------
# |"DATA"                                              |
# ------------------------------------------------------
# |{                                                   |
# |  "sources": [                                      |
# |    {                                               |
# |      "distance": 2521,                             |
# |      "dwd_station_id": "13696",                    |
# |      "first_record": "2010-01-01T00:00:00+00:00",  |
# |      "height": 60,                                 |
# |      "id": 46604,                                  |
# |      "last_record": "2022-11-20T23:00:00+00:00",   |
# |      "lat": 51.5966,                               |
# |      "lon": 7.4048,                                |
# |      "observation_type": "historical",             |
# |      "station_name": "Waltrop-Abdinghof",          |
# |      "wmo_station_id": "H443"                      |
# |    },                                              |
# |    {                                               |
# |      "distance": 14187,                            |
# |      "dwd_station_id": "03795",                    |
# |      "first_record": "2010-01-01T00:00:00+00:00",  |
# |      "height": 48.5,                               |
# |      "id": 8228,                                   |
# |      "last_record": "2022-11-20T23:00:00+00:00",   |
# |      "lat": 51.7066,                               |
# |      "lon": 7.3564,                                |
# |      "observation_type": "historical",             |
# |      "station_name": "Olfen",                      |
# |      "wmo_station_id": "H333"                      |
# |    },                                              |
# |    {                                               |
# |      "distance": 21211,                            |
# |      "dwd_station_id": "13901",                    |
# |      "first_record": "2010-01-01T00:00:00+00:00",  |
# |      "height": 41,                                 |
# |      "id": 9053,                                   |
# |      "last_record": "2022-11-20T23:00:00+00:00",   |
# |      "lat": 51.7343,                               |
# |      "lon": 7.1998,                                |
# |      "observation_type": "historical",             |
# |      "station_name": "Haltern (Wasserwerk)",       |
# |      "wmo_station_id": "H330"                      |
# |    },                                              |
# |    {                                               |
# |      "distance": 34642,                            |
# |      "dwd_station_id": "01303",                    |
# |      "first_record": "2010-01-01T00:00:00+00:00",  |
# |      "height": 150,                                |
# |      "id": 6963,                                   |
# |      "last_record": "2022-11-20T23:00:00+00:00",   |
# |      "lat": 51.4041,                               |
# |      "lon": 6.9677,                                |
# |      "observation_type": "historical",             |
# |      "station_name": "Essen-Bredeney",             |
# |      "wmo_station_id": "10410"                     |
# |    }                                               |
# |  ],                                                |
# |  "weather": [                                      |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "dry",                           |
# |      "dew_point": 7,                               |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1006.6,                       |
# |      "relative_humidity": 67,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 13,                            |
# |      "timestamp": "2022-10-01T00:00:00+00:00",     |
# |      "visibility": 50340,                          |
# |      "wind_direction": 170,                        |
# |      "wind_gust_direction": 160,                   |
# |      "wind_gust_speed": 33.5,                      |
# |      "wind_speed": 15.8                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 87,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 7,                               |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1005.9,                       |
# |      "relative_humidity": 68,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.8,                          |
# |      "timestamp": "2022-10-01T01:00:00+00:00",     |
# |      "visibility": 16840,                          |
# |      "wind_direction": 180,                        |
# |      "wind_gust_direction": 180,                   |
# |      "wind_gust_speed": 36,                        |
# |      "wind_speed": 15.8                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 87,                            |
# |      "condition": "rain",                          |
# |      "dew_point": 8.6,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "rain",                               |
# |      "precipitation": 0.8,                         |
# |      "pressure_msl": 1004.3,                       |
# |      "relative_humidity": 84,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 11.1,                          |
# |      "timestamp": "2022-10-01T02:00:00+00:00",     |
# |      "visibility": 14200,                          |
# |      "wind_direction": 190,                        |
# |      "wind_gust_direction": 200,                   |
# |      "wind_gust_speed": 28.1,                      |
# |      "wind_speed": 13.3                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 87,                            |
# |      "condition": "rain",                          |
# |      "dew_point": 8.8,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "rain",                               |
# |      "precipitation": 1.1,                         |
# |      "pressure_msl": 1004.2,                       |
# |      "relative_humidity": 88,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 10.8,                          |
# |      "timestamp": "2022-10-01T03:00:00+00:00",     |
# |      "visibility": 6290,                           |
# |      "wind_direction": 190,                        |
# |      "wind_gust_direction": 180,                   |
# |      "wind_gust_speed": 37.1,                      |
# |      "wind_speed": 12.6                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 87,                            |
# |      "condition": "rain",                          |
# |      "dew_point": 9.2,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "rain",                               |
# |      "precipitation": 1.6,                         |
# |      "pressure_msl": 1003.3,                       |
# |      "relative_humidity": 92,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 10.5,                          |
# |      "timestamp": "2022-10-01T04:00:00+00:00",     |
# |      "visibility": 5090,                           |
# |      "wind_direction": 190,                        |
# |      "wind_gust_direction": 180,                   |
# |      "wind_gust_speed": 41.8,                      |
# |      "wind_speed": 18.4                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "rain",                          |
# |      "dew_point": 9.5,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "rain",                               |
# |      "precipitation": 1.4,                         |
# |      "pressure_msl": 1002.5,                       |
# |      "relative_humidity": 91,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 10.9,                          |
# |      "timestamp": "2022-10-01T05:00:00+00:00",     |
# |      "visibility": 48810,                          |
# |      "wind_direction": 200,                        |
# |      "wind_gust_direction": 180,                   |
# |      "wind_gust_speed": 39.2,                      |
# |      "wind_speed": 17.6                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "rain",                          |
# |      "dew_point": 9.9,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0.5,                         |
# |      "pressure_msl": 1002.8,                       |
# |      "relative_humidity": 91,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 11.3,                          |
# |      "timestamp": "2022-10-01T06:00:00+00:00",     |
# |      "visibility": 6510,                           |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 210,                   |
# |      "wind_gust_speed": 31.7,                      |
# |      "wind_speed": 15.1                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "rain",                          |
# |      "dew_point": 10.5,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0.4,                         |
# |      "pressure_msl": 1003.2,                       |
# |      "relative_humidity": 94,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 11.5,                          |
# |      "timestamp": "2022-10-01T07:00:00+00:00",     |
# |      "visibility": 51530,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 240,                   |
# |      "wind_gust_speed": 30.6,                      |
# |      "wind_speed": 14.8                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "rain",                          |
# |      "dew_point": 10.8,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0.1,                         |
# |      "pressure_msl": 1003.8,                       |
# |      "relative_humidity": 93,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12,                            |
# |      "timestamp": "2022-10-01T08:00:00+00:00",     |
# |      "visibility": 33140,                          |
# |      "wind_direction": 230,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 29.5,                      |
# |      "wind_speed": 13.3                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "dry",                           |
# |      "dew_point": 11.5,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1004.3,                       |
# |      "relative_humidity": 91,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.9,                          |
# |      "timestamp": "2022-10-01T09:00:00+00:00",     |
# |      "visibility": 45190,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 29.5,                      |
# |      "wind_speed": 16.9                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "dry",                           |
# |      "dew_point": 12.1,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1004.8,                       |
# |      "relative_humidity": 87,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 14.3,                          |
# |      "timestamp": "2022-10-01T10:00:00+00:00",     |
# |      "visibility": 7760,                           |
# |      "wind_direction": 230,                        |
# |      "wind_gust_direction": 230,                   |
# |      "wind_gust_speed": 40,                        |
# |      "wind_speed": 14.8                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 87,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 12.4,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1005.2,                       |
# |      "relative_humidity": 85,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 12,                               |
# |      "temperature": 14.8,                          |
# |      "timestamp": "2022-10-01T11:00:00+00:00",     |
# |      "visibility": 38830,                          |
# |      "wind_direction": 230,                        |
# |      "wind_gust_direction": 250,                   |
# |      "wind_gust_speed": 30.2,                      |
# |      "wind_speed": 15.1                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 87,                            |
# |      "condition": "rain",                          |
# |      "dew_point": 12.2,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0.1,                         |
# |      "pressure_msl": 1005.5,                       |
# |      "relative_humidity": 81,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 22,                               |
# |      "temperature": 15.5,                          |
# |      "timestamp": "2022-10-01T12:00:00+00:00",     |
# |      "visibility": 31210,                          |
# |      "wind_direction": 250,                        |
# |      "wind_gust_direction": 250,                   |
# |      "wind_gust_speed": 41,                        |
# |      "wind_speed": 19.1                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 75,                            |
# |      "condition": "rain",                          |
# |      "dew_point": 11.7,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "partly-cloudy-day",                  |
# |      "precipitation": 0.5,                         |
# |      "pressure_msl": 1006,                         |
# |      "relative_humidity": 85,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 18,                               |
# |      "temperature": 14.1,                          |
# |      "timestamp": "2022-10-01T13:00:00+00:00",     |
# |      "visibility": 48130,                          |
# |      "wind_direction": 240,                        |
# |      "wind_gust_direction": 240,                   |
# |      "wind_gust_speed": 20.5,                      |
# |      "wind_speed": 10.8                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 87,                            |
# |      "condition": "rain",                          |
# |      "dew_point": 12,                              |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "condition": 6963,                          |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 9053,                     |
# |        "wind_gust_direction": 9053,                |
# |        "wind_gust_speed": 9053,                    |
# |        "wind_speed": 9053                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0.5,                         |
# |      "pressure_msl": 1007,                         |
# |      "relative_humidity": 83,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 26,                               |
# |      "temperature": 14.8,                          |
# |      "timestamp": "2022-10-01T14:00:00+00:00",     |
# |      "visibility": 34510,                          |
# |      "wind_direction": 260,                        |
# |      "wind_gust_direction": 270,                   |
# |      "wind_gust_speed": 47.5,                      |
# |      "wind_speed": 15.5                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 12,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 11,                              |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-day",                          |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1007.6,                       |
# |      "relative_humidity": 71,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 59,                               |
# |      "temperature": 16.2,                          |
# |      "timestamp": "2022-10-01T15:00:00+00:00",     |
# |      "visibility": 33930,                          |
# |      "wind_direction": 260,                        |
# |      "wind_gust_direction": 250,                   |
# |      "wind_gust_speed": 36.4,                      |
# |      "wind_speed": 14.4                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 37,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 10.4,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "partly-cloudy-day",                  |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1008.6,                       |
# |      "relative_humidity": 70,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 55,                               |
# |      "temperature": 15.8,                          |
# |      "timestamp": "2022-10-01T16:00:00+00:00",     |
# |      "visibility": 51740,                          |
# |      "wind_direction": 250,                        |
# |      "wind_gust_direction": 250,                   |
# |      "wind_gust_speed": 33.8,                      |
# |      "wind_speed": 15.5                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 12,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 9.9,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-day",                          |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1009.7,                       |
# |      "relative_humidity": 72,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 40,                               |
# |      "temperature": 14.9,                          |
# |      "timestamp": "2022-10-01T17:00:00+00:00",     |
# |      "visibility": 40760,                          |
# |      "wind_direction": 260,                        |
# |      "wind_gust_direction": 270,                   |
# |      "wind_gust_speed": 30.6,                      |
# |      "wind_speed": 11.9                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 9.4,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1011,                         |
# |      "relative_humidity": 73,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 14.3,                          |
# |      "timestamp": "2022-10-01T18:00:00+00:00",     |
# |      "visibility": 38740,                          |
# |      "wind_direction": 250,                        |
# |      "wind_gust_direction": 260,                   |
# |      "wind_gust_speed": 20.9,                      |
# |      "wind_speed": 10.1                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 9.4,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1012.2,                       |
# |      "relative_humidity": 78,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 13.1,                          |
# |      "timestamp": "2022-10-01T19:00:00+00:00",     |
# |      "visibility": 35680,                          |
# |      "wind_direction": 240,                        |
# |      "wind_gust_direction": 270,                   |
# |      "wind_gust_speed": 25.9,                      |
# |      "wind_speed": 8.6                             |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 9.5,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1013,                         |
# |      "relative_humidity": 80,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.9,                          |
# |      "timestamp": "2022-10-01T20:00:00+00:00",     |
# |      "visibility": 33510,                          |
# |      "wind_direction": 230,                        |
# |      "wind_gust_direction": 240,                   |
# |      "wind_gust_speed": 20.9,                      |
# |      "wind_speed": 11.2                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 9.7,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1013.6,                       |
# |      "relative_humidity": 85,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.2,                          |
# |      "timestamp": "2022-10-01T21:00:00+00:00",     |
# |      "visibility": 31620,                          |
# |      "wind_direction": 230,                        |
# |      "wind_gust_direction": 230,                   |
# |      "wind_gust_speed": 24.5,                      |
# |      "wind_speed": 12.6                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 37,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 9.4,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "partly-cloudy-night",                |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1014.2,                       |
# |      "relative_humidity": 81,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.6,                          |
# |      "timestamp": "2022-10-01T22:00:00+00:00",     |
# |      "visibility": 30870,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 21.6,                      |
# |      "wind_speed": 12.6                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 25,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 9.9,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "partly-cloudy-night",                |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1014.8,                       |
# |      "relative_humidity": 85,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.3,                          |
# |      "timestamp": "2022-10-01T23:00:00+00:00",     |
# |      "visibility": 31360,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 200,                   |
# |      "wind_gust_speed": 25.9,                      |
# |      "wind_speed": 13                              |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 12,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 10,                              |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1014.9,                       |
# |      "relative_humidity": 84,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.7,                          |
# |      "timestamp": "2022-10-02T00:00:00+00:00",     |
# |      "visibility": 26310,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 210,                   |
# |      "wind_gust_speed": 25.6,                      |
# |      "wind_speed": 13.7                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "dry",                           |
# |      "dew_point": 10.8,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1015.1,                       |
# |      "relative_humidity": 88,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.7,                          |
# |      "timestamp": "2022-10-02T01:00:00+00:00",     |
# |      "visibility": 19400,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 230,                   |
# |      "wind_gust_speed": 22,                        |
# |      "wind_speed": 12.6                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "dry",                           |
# |      "dew_point": 11.4,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1015.3,                       |
# |      "relative_humidity": 91,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 12.8,                          |
# |      "timestamp": "2022-10-02T02:00:00+00:00",     |
# |      "visibility": 17270,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 22.7,                      |
# |      "wind_speed": 12.6                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "dry",                           |
# |      "dew_point": 11.8,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1015.3,                       |
# |      "relative_humidity": 92,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 13.1,                          |
# |      "timestamp": "2022-10-02T03:00:00+00:00",     |
# |      "visibility": 15960,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 23,                        |
# |      "wind_speed": 12.2                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 100,                           |
# |      "condition": "dry",                           |
# |      "dew_point": 12.2,                            |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "cloudy",                             |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1015.2,                       |
# |      "relative_humidity": 92,                      |
# |      "source_id": 46604,                           |
# ...
# |      "timestamp": "2022-10-06T14:00:00+00:00",     |
# |      "visibility": 56100,                          |
# |      "wind_direction": 230,                        |
# |      "wind_gust_direction": 230,                   |
# |      "wind_gust_speed": 27,                        |
# |      "wind_speed": 13.3                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 5.4,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-day",                          |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1030.09,                      |
# |      "relative_humidity": 46,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 60,                               |
# |      "temperature": 17,                            |
# |      "timestamp": "2022-10-06T15:00:00+00:00",     |
# |      "visibility": 46970,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 25.9,                      |
# |      "wind_speed": 13.7                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 5.3,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-day",                          |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1029.9,                       |
# |      "relative_humidity": 47,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 60,                               |
# |      "temperature": 16.5,                          |
# |      "timestamp": "2022-10-06T16:00:00+00:00",     |
# |      "visibility": 45920,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 22.3,                      |
# |      "wind_speed": 12.2                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 7.1,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1030.09,                      |
# |      "relative_humidity": 64,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 47,                               |
# |      "temperature": 13.7,                          |
# |      "timestamp": "2022-10-06T17:00:00+00:00",     |
# |      "visibility": 59820,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 230,                   |
# |      "wind_gust_speed": 20.2,                      |
# |      "wind_speed": 10.8                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 6.5,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1030.2,                       |
# |      "relative_humidity": 79,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 10,                            |
# |      "timestamp": "2022-10-06T18:00:00+00:00",     |
# |      "visibility": 59140,                          |
# |      "wind_direction": 230,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 16.9,                      |
# |      "wind_speed": 10.1                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 6,                               |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1030.3,                       |
# |      "relative_humidity": 86,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 8.2,                           |
# |      "timestamp": "2022-10-06T19:00:00+00:00",     |
# |      "visibility": 49590,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 220,                   |
# |      "wind_gust_speed": 16.9,                      |
# |      "wind_speed": 9                               |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 25,                            |
# |      "condition": "dry",                           |
# |      "dew_point": 6.1,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "partly-cloudy-night",                |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1030.2,                       |
# |      "relative_humidity": 89,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 7.7,                           |
# |      "timestamp": "2022-10-06T20:00:00+00:00",     |
# |      "visibility": 50240,                          |
# |      "wind_direction": 230,                        |
# |      "wind_gust_direction": 230,                   |
# |      "wind_gust_speed": 18.4,                      |
# |      "wind_speed": 10.1                            |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 5.6,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1030.4,                       |
# |      "relative_humidity": 92,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 6.8,                           |
# |      "timestamp": "2022-10-06T21:00:00+00:00",     |
# |      "visibility": 38920,                          |
# |      "wind_direction": 220,                        |
# |      "wind_gust_direction": 230,                   |
# |      "wind_gust_speed": 15.1,                      |
# |      "wind_speed": 8.6                             |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 5.3,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1030,                         |
# |      "relative_humidity": 92,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 6.4,                           |
# |      "timestamp": "2022-10-06T22:00:00+00:00",     |
# |      "visibility": 44940,                          |
# |      "wind_direction": 210,                        |
# |      "wind_gust_direction": 230,                   |
# |      "wind_gust_speed": 13.3,                      |
# |      "wind_speed": 6.5                             |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 5,                               |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1029.5,                       |
# |      "relative_humidity": 94,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 5.9,                           |
# |      "timestamp": "2022-10-06T23:00:00+00:00",     |
# |      "visibility": 38000,                          |
# |      "wind_direction": 170,                        |
# |      "wind_gust_direction": 170,                   |
# |      "wind_gust_speed": 12.6,                      |
# |      "wind_speed": 6.5                             |
# |    },                                              |
# |    {                                               |
# |      "cloud_cover": 0,                             |
# |      "condition": "dry",                           |
# |      "dew_point": 4.8,                             |
# |      "fallback_source_ids": {                      |
# |        "cloud_cover": 6963,                        |
# |        "pressure_msl": 6963,                       |
# |        "sunshine": 6963,                           |
# |        "visibility": 6963,                         |
# |        "wind_direction": 6963,                     |
# |        "wind_gust_direction": 6963,                |
# |        "wind_gust_speed": 6963,                    |
# |        "wind_speed": 6963                          |
# |      },                                            |
# |      "icon": "clear-night",                        |
# |      "precipitation": 0,                           |
# |      "pressure_msl": 1029,                         |
# |      "relative_humidity": 93,                      |
# |      "source_id": 46604,                           |
# |      "sunshine": 0,                                |
# |      "temperature": 5.8,                           |
# |      "timestamp": "2022-10-07T00:00:00+00:00",     |
# |      "visibility": 39500,                          |
# |      "wind_direction": 170,                        |
# |      "wind_gust_direction": 190,                   |
# |      "wind_gust_speed": 14,                        |
# |      "wind_speed": 6.8                             |
# |    }                                               |
# |  ]                                                 |
# |}                                                   |
# ------------------------------------------------------

# %%
# TODO: Step 1 = Flatten the sources column
step1 = json_df.join_table_function(
    "flatten",
    col("data"),
    lit("sources")
).select("index","path","value")

# %%
# TODO: Show the result of Step 1 to check it worked
step1.show()
# Out:
# -------------------------------------------------------------------------
# |"INDEX"  |"PATH"      |"VALUE"                                         |
# -------------------------------------------------------------------------
# |0        |sources[0]  |{                                               |
# |         |            |  "distance": 2521,                             |
# |         |            |  "dwd_station_id": "13696",                    |
# |         |            |  "first_record": "2010-01-01T00:00:00+00:00",  |
# |         |            |  "height": 60,                                 |
# |         |            |  "id": 46604,                                  |
# |         |            |  "last_record": "2022-11-20T23:00:00+00:00",   |
# |         |            |  "lat": 51.5966,                               |
# |         |            |  "lon": 7.4048,                                |
# |         |            |  "observation_type": "historical",             |
# |         |            |  "station_name": "Waltrop-Abdinghof",          |
# |         |            |  "wmo_station_id": "H443"                      |
# |         |            |}                                               |
# |1        |sources[1]  |{                                               |
# |         |            |  "distance": 14187,                            |
# |         |            |  "dwd_station_id": "03795",                    |
# |         |            |  "first_record": "2010-01-01T00:00:00+00:00",  |
# |         |            |  "height": 48.5,                               |
# |         |            |  "id": 8228,                                   |
# |         |            |  "last_record": "2022-11-20T23:00:00+00:00",   |
# |         |            |  "lat": 51.7066,                               |
# |         |            |  "lon": 7.3564,                                |
# |         |            |  "observation_type": "historical",             |
# |         |            |  "station_name": "Olfen",                      |
# |         |            |  "wmo_station_id": "H333"                      |
# |         |            |}                                               |
# |2        |sources[2]  |{                                               |
# |         |            |  "distance": 21211,                            |
# |         |            |  "dwd_station_id": "13901",                    |
# |         |            |  "first_record": "2010-01-01T00:00:00+00:00",  |
# |         |            |  "height": 41,                                 |
# |         |            |  "id": 9053,                                   |
# |         |            |  "last_record": "2022-11-20T23:00:00+00:00",   |
# |         |            |  "lat": 51.7343,                               |
# |         |            |  "lon": 7.1998,                                |
# |         |            |  "observation_type": "historical",             |
# |         |            |  "station_name": "Haltern (Wasserwerk)",       |
# |         |            |  "wmo_station_id": "H330"                      |
# |         |            |}                                               |
# |3        |sources[3]  |{                                               |
# |         |            |  "distance": 34642,                            |
# |         |            |  "dwd_station_id": "01303",                    |
# |         |            |  "first_record": "2010-01-01T00:00:00+00:00",  |
# |         |            |  "height": 150,                                |
# |         |            |  "id": 6963,                                   |
# |         |            |  "last_record": "2022-11-20T23:00:00+00:00",   |
# |         |            |  "lat": 51.4041,                               |
# |         |            |  "lon": 6.9677,                                |
# |         |            |  "observation_type": "historical",             |
# |         |            |  "station_name": "Essen-Bredeney",             |
# |         |            |  "wmo_station_id": "10410"                     |
# |         |            |}                                               |
# -------------------------------------------------------------------------

# %%
# TODO: Step 2, extract each column
step2 = (
    step1.withColumn(
        "distance",
        json_extract_path_text("value",lit("distance"))
    )
    .withColumn(
        "dwd_station_id",
        json_extract_path_text("value",lit("dwd_station_id"))
    )
    .withColumn(
        "first_record",
        json_extract_path_text("value",lit("first_record"))
    )
    .withColumn(
        "height",
        json_extract_path_text("value",lit("height"))
    )
    .withColumn(
        "id",
        json_extract_path_text("value",lit("id"))
    )
    .withColumn(
        "last_record",
        json_extract_path_text("value",lit("last_record"))
    )
    .withColumn(
        "lat",
        json_extract_path_text("value",lit("lat"))
    )
    .withColumn(
        "lon",
        json_extract_path_text("value",lit("lon"))
    )
    .withColumn(
        "observation_type",
        json_extract_path_text("value",lit("observation_type"))
    )
    .withColumn(
        "station_name",
        json_extract_path_text("value",lit("station_name"))
    )
    .withColumn(
        "wmo_station_id",
        json_extract_path_text("value",lit("wmo_station_id"))
    )
).drop("value")

# %%
# TODO: Show the results to check
step2.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"INDEX"  |"PATH"      |"DISTANCE"  |"DWD_STATION_ID"  |"FIRST_RECORD"             |"HEIGHT"  |"ID"   |"LAST_RECORD"              |"LAT"    |"LON"   |"OBSERVATION_TYPE"  |"STATION_NAME"        |"WMO_STATION_ID"  |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |0        |sources[0]  |2521        |13696             |2010-01-01T00:00:00+00:00  |60        |46604  |2022-11-20T23:00:00+00:00  |51.5966  |7.4048  |historical          |Waltrop-Abdinghof     |H443              |
# |1        |sources[1]  |14187       |03795             |2010-01-01T00:00:00+00:00  |48.5      |8228   |2022-11-20T23:00:00+00:00  |51.7066  |7.3564  |historical          |Olfen                 |H333              |
# |2        |sources[2]  |21211       |13901             |2010-01-01T00:00:00+00:00  |41        |9053   |2022-11-20T23:00:00+00:00  |51.7343  |7.1998  |historical          |Haltern (Wasserwerk)  |H330              |
# |3        |sources[3]  |34642       |01303             |2010-01-01T00:00:00+00:00  |150       |6963   |2022-11-20T23:00:00+00:00  |51.4041  |6.9677  |historical          |Essen-Bredeney        |10410             |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Window Function

# %%
# Create data frames for `catalog_sales`, `warehouse` and `date_dim` tables from the `tpcds_sf10tcl` schema
catalog_sales_df = (
    demo_session.table("snowflake_sample_data.tpcds_sf10tcl.catalog_sales")
    .select("cs_order_number", "cs_ext_tax", "cs_warehouse_sk", "cs_sold_date_sk")
)
warehouse_df = (
    demo_session.table("snowflake_sample_data.tpcds_sf10tcl.warehouse")
    .select("w_warehouse_name", "w_state", "w_warehouse_sk")
)
date_dim_df = (
    demo_session.table("snowflake_sample_data.tpcds_sf10tcl.date_dim")
    .select("d_date", "d_date_sk")
    .filter((date_part("YEAR", "d_date") == 2001) & (date_part("MONTH", "d_date") == 3)) # This one is filtered to the required month-year
)
# Join the three data frames together, get rid of surrogate key columns and rename kept columns
catalog_df = (
    catalog_sales_df.join(
        warehouse_df,
        catalog_sales_df.cs_warehouse_sk == warehouse_df.w_warehouse_sk
    )
    .join(
        date_dim_df,
        catalog_sales_df.cs_sold_date_sk == date_dim_df.d_date_sk
    )
    .select("cs_order_number", "d_date", "w_warehouse_name", "w_state", "cs_ext_tax")
    .to_df("order_number", "date", "warehouse_name", "state", "ext_tax")
)

# %%
catalog_df.show()
# Out:
# ----------------------------------------------------------------------------
# |"ORDER_NUMBER"  |"DATE"      |"WAREHOUSE_NAME"      |"STATE"  |"EXT_TAX"  |
# ----------------------------------------------------------------------------
# |991787670       |2001-03-12  |New, net purposes     |LA       |18.98      |
# |991642555       |2001-03-12  |New, net purposes     |LA       |10.67      |
# |991471048       |2001-03-12  |Other, alon           |CO       |586.16     |
# |991947222       |2001-03-12  |Rooms cook            |TN       |60.27      |
# |991706568       |2001-03-12  |Local, mass universi  |WV       |389.78     |
# |991935157       |2001-03-12  |Months woul           |NM       |29.17      |
# |991556585       |2001-03-12  |Months woul           |NM       |14.13      |
# |991933739       |2001-03-12  |Soon regular workers  |IN       |17.65      |
# |991629629       |2001-03-12  |Important dem         |NC       |2.47       |
# |991935965       |2001-03-12  |Important dem         |NC       |4.19       |
# ----------------------------------------------------------------------------

# %%
# Aggregate the data frame
catalog_df_agg = (
    catalog_df.group_by("state","warehouse_name")
    .agg(median("ext_tax").alias("median_ext_tax"))
)

# %%
# Show the result to check this has worked
catalog_df_agg.order_by("median_ext_tax").show()
# Out:
# -----------------------------------------------------
# |"STATE"  |"WAREHOUSE_NAME"      |"MEDIAN_EXT_TAX"  |
# -----------------------------------------------------
# |FL       |Surprising emot       |34.31000          |
# |IN       |Soon regular workers  |34.32000          |
# |LA       |Conventional childr   |34.35000          |
# |NM       |Months woul           |34.35000          |
# |LA       |New, net purposes     |34.36000          |
# |NE       |Bad cards must make.  |34.36000          |
# |MI       |Plain, reluctant      |34.36000          |
# |NY       |Agricultural measur   |34.37000          |
# |NC       |Important dem         |34.37000          |
# |TN       |Rooms cook            |34.37000          |
# -----------------------------------------------------

# %%
# TODO: Define the window, partitioned by state and ordered by that `median_ext_tax` column
window = Window.partition_by("state").order_by("median_ext_tax")

# %%
# TODO: Rank the dataframe according to the window, call this `ranked_df`
ranked_df = catalog_df_agg.select("state","warehouse_name",rank().over(window).as_("rank_by_state"))

# %%
# Show the result
ranked_df.order_by("state","rank_by_state").show(30)
# Out:
# ----------------------------------------------------
# |"STATE"  |"WAREHOUSE_NAME"      |"RANK_BY_STATE"  |
# ----------------------------------------------------
# |CO       |Total sports leap a   |1                |
# |CO       |Other, alon           |1                |
# |CO       |Please central m      |3                |
# |CO       |NULL                  |4                |
# |CO       |Governments should    |5                |
# |FL       |Surprising emot       |1                |
# |GA       |New proceedings fo    |1                |
# |IN       |Soon regular workers  |1                |
# |LA       |Conventional childr   |1                |
# |LA       |New, net purposes     |2                |
# |MI       |Plain, reluctant      |1                |
# |MO       |Therefore urg         |1                |
# |MO       |Empty, middle women   |2                |
# |NC       |Important dem         |1                |
# |NC       |Unexpected sup        |2                |
# |NE       |Bad cards must make.  |1                |
# |NM       |Months woul           |1                |
# |NY       |Agricultural measur   |1                |
# |SD       |Important issues liv  |1                |
# |SD       |Friendly, suitable    |2                |
# |TN       |Rooms cook            |1                |
# |WV       |Doors canno           |1                |
# |WV       |Local, mass universi  |1                |
# |WV       |Quite effectiv        |3                |
# |WV       |National, comple      |4                |
# ----------------------------------------------------

# %%
#demo_session.close()
