# %%
# Import login values from config
from configparser import *

# %%
# Import packages needed
from snowflake.snowpark import Session
from snowflake.snowpark.functions import *
from snowflake.snowpark.types import *
from snowflake.snowpark import Window
import pandas as pd
from urllib import request
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import numpy as np

# %%
#we save credentials in a credentials_dict dictionary
import sys, json
with open("connection_parameters_prod.json") as jsonfile:
    credentials_dict = json.load(jsonfile)

# %%
#we connect to snowflake using credentials_dict and declare a session
def snowpark_session_create():
    session = Session.builder.configs(credentials_dict).create()
    return session

# %%
#we create a session
session = snowpark_session_create()

# %%
#we declare what db and what schema we will be using, we can change this within sql
session.use_database("SNF_MDRAZ")
session.use_schema("bronze")

# %%
#we are defining an sql query which will be used to create a bronze table where data will come from staging
#IF NOT EXISTS
session.sql("""
    create or replace TABLE SNF_MDRAZ.BRONZE.KNA1 (
	INDEX VARCHAR(16777216),
	KUNNR VARCHAR(16777216),
	GENDE VARCHAR(16777216),
	NAME1 VARCHAR(16777216),
	NAME2 VARCHAR(16777216),
	STRAS VARCHAR(16777216),
	ORT01 VARCHAR(16777216),
	PSTLZ VARCHAR(16777216),
	LAND1 VARCHAR(16777216),
	LAND2 VARCHAR(16777216),
	RSCON VARCHAR(16777216),
	TELF1 VARCHAR(16777216),
	REGIO VARCHAR(16777216),
	BIRTH DATE,
	LATI VARCHAR(16777216),
	LONG VARCHAR(16777216),
	LASTMODIFIED DATE
);
"""
).collect()
# Out:
# [Row(status='Table KNA1 successfully created.')]

# %%
#we execute sql query for bronze creation and use collect() to force execution
#session.sql(create_or_replace_table).collect()
# Out:
# [Row(status='KNA1 already exists, statement succeeded.')]

# %%
#we are selecting data from staging table kna1
source_table = """select
    index,
    kunnr,
    gende,
    name1,
    name2,
    stras,
    ort01,
    pstlz,
    land1,
    land2,
    rscon,
    telf1,
    regio,
    to_date(birth,'YYYY/MM/DD') birth,
    lati,
    long,
    current_date() as LASTMODIFIED from staging.kna1;"""
df_source = session.sql(source_table).to_pandas()

# %%
#we are listing what values we want to use to replace NaNs and Nulls
values = {
    'INDEX': -99,
    'KUNNR': 'NA',
    'GENDE': 'NA', 
    'NAME1': 'NA', 
    'NAME2': 'NA', 
    'STRAS': 'NA', 
    'ORT01': 'NA', 
    'PSTLZ': 'NA', 
    'LAND1': 'NA', 
    'LAND2': 'NA', 
    'RSCON': 'NA', 
    'TELF1': 'NA', 
    'REGIO': -99, 
    'BIRTH': '1900/01/01', 
    'LATI': 0, 
    'LONG': 0, 
    'LASTMODIFIED' : '1900/01/01'
}
df_source.fillna(value=values,inplace=True)

# %%
#since couple of columns have wrong types, here we are changing these types to what we need
#also couple of data has ' in them, we are replacing them with '' to avoid accidental break in string
df_source['INDEX'] = df_source['INDEX'].astype('int64')
df_source['REGIO'] = df_source['REGIO'].astype('str')
df_source['GENDE'] = df_source['GENDE'].astype('str')
df_source['BIRTH'] = pd.to_datetime(df_source['BIRTH'],format='ISO8601').dt.strftime('%Y-%m-%d')
df_source['ORT01'] = df_source['ORT01'].replace("'","''")
df_source = df_source.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
#another way of inserting data into snowflake
try:
    session.sql("BEGIN TRANSACTION")
    spDF = session.write_pandas(
        df = df_source,
        table_name="kna1",
        database="snf_mdraz",
        schema="bronze",
        quote_identifiers=False,
        overwrite=True
    )
    session.sql("COMMIT")
except Exception as e:
        session.sql("Rollback")
        print(f"Error encountered: {e}. All inserts have been rolled back.")

# %%
#we are creating a temp table with
temp_tbl = "temp_kna1_cleaned"
df_temp = session.create_dataframe(df_source)
df_temp.write.mode("overwrite").saveAsTable(temp_tbl)

# %%
session.sql("truncate bronze.kna1;").collect()
bulk_insert_sql = f"""
                    insert into snf_mdraz.bronze.kna1 (INDEX,KUNNR,GENDE,NAME1,NAME2,STRAS,ORT01,PSTLZ,LAND1,LAND2,RSCON,TELF1,REGIO,BIRTH,LATI,LONG,LASTMODIFIED) 
                    select 
                        index,
                        kunnr,    
                        gende,    
                        name1,    
                        name2,    
                        stras,    
                        ort01,    
                        pstlz,    
                        land1,    
                        land2,    
                        rscon,    
                        telf1,    
                        regio,    
                        birth,    
                        lati,    
                        long,
                        LASTMODIFIED
                    from {temp_tbl}
                    """
try:
    session.sql("BEGIN TRANSACTION")
    session.sql(bulk_insert_sql).collect()
    session.sql("COMMIT")
except Exception as e:
        session.sql("Rollback")
        print(f"Error encountered: {e}. All inserts have been rolled back.")  
session.sql(f"DROP TABLE IF EXISTS {temp_tbl}").collect()
# Out:
# [Row(status='TEMP_KNA1_CLEANED successfully dropped.')]

# %%
tablica = session.table("bronze.kna1")
tablica.show()
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"INDEX"  |"KUNNR"  |"GENDE"  |"NAME1"     |"NAME2"    |"STRAS"                      |"ORT01"            |"PSTLZ"   |"LAND1"  |"LAND2"         |"RSCON"                        |"TELF1"        |"REGIO"  |"BIRTH"     |"LATI"     |"LONG"     |"LASTMODIFIED"  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |486557   |C586557  |Female   |Lihue       |Brito      |Cercas Bajas 40              |Parets del Vallès  |08150     |ES       |Spain           |LihueBritoSantillan@rhyta.com  |672 370 879    |34.0     |1980-08-27  |41.574389  |2.317931   |2023-09-12      |
# |486563   |C586563  |Male     |Zayd        |Meijnen    |Mering 122                   |Hippolytushoef     |1777 DJ   |NL       |Netherlands     |ZaydMeijnen@fleckens.hu        |06-99774639    |31.0     |1998-08-20  |52.815899  |4.871533   |2023-09-12      |
# |486565   |C586565  |Female   |Daniela     |Greco      |Stradone Antonio Provolo 80  |Papigno            |5037      |IT       |Italy           |DanielaGreco@armyspy.com       |0330 4194859   |39.0     |1995-06-01  |42.595653  |12.741931  |2023-09-12      |
# |486567   |C586567  |Male     |Lubomir     |Zawadzki   |Via Scala 89                 |Savona             |NA        |IT       |Italy           |LubomirZawadzki@superrito.com  |0311 4770956   |39.0     |1981-08-07  |44.337515  |8.439614   |2023-09-12      |
# |-99      |C586571  |Other    |Milton      |Löfgren    |Rue de la Sarthe 380         |Horpmaal           |3870      |BE       |Belgium         |MiltonLofgren@gustr.com        |0489 66 35 54  |32.0     |1985-12-17  |50.832168  |5.1863     |2023-09-12      |
# |486572   |C586572  |Male     |Aleksandar  |Nyman      |Backsippestigen 66           |MANTORP            |590 20    |SE       |Sweden          |AleksandarNyman@fleckens.hu    |0142-7450165   |NA       |1993-10-31  |58.318814  |0.0        |2023-09-12      |
# |486574   |C586574  |Male     |Louie       |Walsh      |37 Baldock Street            |NEWTON LONGVILLE   |MK17 3TW  |GB       |United Kingdom  |LouieWalsh@dayrep.com          |079 0702 8687  |44.0     |1992-08-15  |52.037848  |-0.925469  |2023-09-12      |
# |486578   |C586578  |Male     |Grzegorz    |Michalski  |Rue Haute 65                 |St-Margriete       |3470      |BE       |Belgium         |GrzegorzMichalski@gustr.com    |0494 72 92 15  |32.0     |1991-04-17  |50.996413  |5.004052   |2023-09-12      |
# |486579   |C586579  |Female   |Klaudia     |Gottlieb   |Lodewijk De Raetlaan 180     |Clermont           |5650      |BE       |Belgium         |KlaudiaGottlieb@armyspy.com    |0480 53 07 94  |32.0     |1992-05-31  |50.351916  |4.448863   |2023-09-12      |
# |486581   |C586581  |Female   |Krysia      |Borkowska  |Piazza Trieste e Trento 8    |Prunetto           |12077     |IT       |Italy           |KrysiaBorkowska@teleworm.us    |0377 1361534   |39.0     |1997-03-18  |0.0        |8.068739   |2023-09-12      |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
session.sql("""
    create or replace TABLE SNF_MDRAZ.SILVER.CUSTOMER (
	ID NUMBER(38,0),
	CUSTOMERID VARCHAR(16777216),
	GENDER VARCHAR(16777216),
	FIRSTNAME VARCHAR(16777216),
	LASTNAME VARCHAR(16777216),
	STREETADDRESS VARCHAR(16777216),
	CITY VARCHAR(16777216),
	POSTALCODE VARCHAR(16777216),
	COUNTRYCODE VARCHAR(16777216),
	COUNTRYNAME VARCHAR(16777216),
	EMAILADDRESS VARCHAR(16777216),
	PHONENUMBER VARCHAR(16777216),
	PHONECOUNTRYCODE NUMBER(38,0),
	DATEOFBIRTH DATE,
	LATITUDE NUMBER(10,6),
	LONGITUDE NUMBER(10,6),
	LASTMODIFIED DATE
);
"""
).collect()
# Out:
# [Row(status='Table CUSTOMER successfully created.')]

# %%
#we are selecting data from staging table kna1
source_table = """select
    index,
    kunnr,
    gende,
    name1,
    name2,
    stras,
    ort01,
    pstlz,
    land1,
    land2,
    rscon,
    telf1,
    regio,
    birth,
    lati,
    long,
    LASTMODIFIED from bronze.kna1;"""
df_bronze = session.sql(source_table).to_pandas()

# %%
df_bronze
# Out:
#          INDEX    KUNNR   GENDE      NAME1      NAME2  \
# 0       767195  C867195  Female    Naiquen     García
# 1       767196  C867196    Male    Jamairo    Vaessen
# 2       767198  C867198  Female    Zuleika     Valdés
# 3       767200  C867200  Female    Julitta  Zielinska
# 4       767201  C867201    Male     Andrew       Hale
# ...        ...      ...     ...        ...        ...
# 429182  767183  C867183  Female  Ghislaine     Lamers
# 429183  767184  C867184    Male       Tuur      Atsma
# 429184  767185  C867185  Female   Seweryna  Kowalczyk
# 429185  767190  C867190    Male     Dmit?i         NA
# 429186  767192  C867192    Male   Emanuele   Trevisan
#
#                              STRAS                  ORT01     PSTLZ LAND1  \
# 0                      Herrería 74                 Diezma     18180    ES
# 1                Hunenborglaan 105              Oldenzaal   7576 XP    NL
# 2             Via Licola Patria 81  San Vito Dei Lombardi     83054    IT
# 3         ul. Królowej Jadwigi 115                 Bedzin    42-500    PL
# 4                60 Spilman Street              GRANSMOOR  YO25 2GZ    GB
# ...                            ...                    ...       ...   ...
# 429182             Beukensingel 28                 Raalte   8102 JA    NL
# 429183             Abdissenlaan 30              Landgraaf   6374 BM    NL
# 429184           Rue du Cornet 275                   Asse      1730    BE
# 429185  Dominee Klinckhamerlaan 91             Appingedam   9901 TD    NL
# 429186              Via Varrone 34             Borgo Lupo     95040    IT
#
#                  LAND2                               RSCON          TELF1  \
# 0                Spain  NaiquenGarciaDuenas@jourrapide.com    632 393 331
# 1          Netherlands           JamairoVaessen@dayrep.com    06-12639151
# 2                Italy      ZuleikaValdesArmenta@rhyta.com   0335 6290189
# 3               Poland                                  NA   79 743 62 34
# 4       United Kingdom              AndrewHale@fleckens.hu  070 8858 9587
# ...                ...                                 ...            ...
# 429182     Netherlands         GhislaineLamers@fleckens.hu    06-77490188
# 429183     Netherlands               TuurAtsma@teleworm.us    06-37440313
# 429184         Belgium          SewerynaKowalczyk@cuvox.de  0498 95 85 49
# 429185     Netherlands         DmitrivanMechelen@rhyta.com    06-76484124
# 429186           Italy     EmanueleTrevisan@jourrapide.com   0357 0654156
#
#        REGIO       BIRTH       LATI       LONG LASTMODIFIED
# 0       34.0  1982-10-03  37.306270  -3.236022   2023-09-12
# 1       31.0  1980-10-20  52.306041   6.923527   2023-09-12
# 2       39.0  1986-09-01  41.028317  15.109596   2023-09-12
# 3       48.0  1990-09-10  50.355541   0.000000   2023-09-12
# 4       44.0  1975-12-17  53.381289  -0.757120   2023-09-12
# ...      ...         ...        ...        ...          ...
# 429182  31.0  1989-11-01  52.473943   6.304586   2023-09-12
# 429183  31.0  1996-08-14  50.887646   6.008784   2023-09-12
# 429184  32.0  1991-07-10  50.980902   4.303276   2023-09-12
# 429185  31.0  1991-11-09  53.398800   6.948384   2023-09-12
# 429186  39.0  1993-11-23  37.151345  14.647698   2023-09-12
#
# [429187 rows x 17 columns]

# %%
df_bronze= df_bronze.sort_values(by=['LASTMODIFIED'], ascending=False)
df_bronze['rn'] = df_bronze.groupby(['INDEX','KUNNR']).cumcount()+1
df_bronze[df_bronze.rn == 1]
df_bronze.reset_index(inplace=True)
# Out:
#           INDEX     KUNNR   GENDE       NAME1      NAME2  \
# 0        767195   C867195  Female     Naiquen     García
# 286159   373024   C473024  Female       Irene     Milano
# 286131   372937   C472937    Male    Nicholas      Nyman
# 286130   372935   C472935      NA          NA       Lees
# 286129   372934   C472934  Female     Pauline      Ström
# ...         ...       ...     ...         ...        ...
# 143059      -99  C1260238    Male        Ryan      Scott
# 143058  1160235  C1260235  Female       Emily     Bryant
# 143057  1160231  C1260231    Male  Konstantyn  Grabowski
# 143056  1160227  C1260227    Male     Cyprien     Urbina
# 429186   767192   C867192    Male    Emanuele   Trevisan
#
#                                        STRAS             ORT01     PSTLZ  \
# 0                                Herrería 74            Diezma     18180
# 286159               Via Goffredo Mameli 121  Misano Adriatico     47843
# 286131                       Alsteråvägen 16            MOTALA    591 67
# 286130                        86 Nith Street        GLASAHOILE   FK8 9HU
# 286129                                    NA         ERIKSMÅLA    361 04
# ...                                      ...               ...       ...
# 143059              97 South Western Terrace         MINFFORDD  LL48 4SG
# 143058                                    NA        KILCHRENAN  PA35 5HY
# 143057  ul. Generala Sulkowskiego Józefa 150          Szczecin    71-129
# 143056                         C/ Angosto 74           Sabiote     23410
# 429186                        Via Varrone 34        Borgo Lupo     95040
#
#        LAND1           LAND2                               RSCON  \
# 0         ES           Spain  NaiquenGarciaDuenas@jourrapide.com
# 286159    IT           Italy              IreneMilano@einrot.com
# 286131    SE          Sweden           NicholasNyman@teleworm.us
# 286130    GB  United Kingdom              JonathanLees@gustr.com
# 286129    SE          Sweden          PaulineStrom@superrito.com
# ...      ...             ...                                 ...
# 143059    GB  United Kingdom                  RyanScott@cuvox.de
# 143058    GB  United Kingdom                                  NA
# 143057    PL          Poland     KonstantynGrabowski@armyspy.com
# 143056    ES           Spain       CyprienUrbinaToro@teleworm.us
# 429186    IT           Italy     EmanueleTrevisan@jourrapide.com
#
#                 TELF1 REGIO       BIRTH       LATI       LONG LASTMODIFIED  rn
# 0         632 393 331  34.0  1982-10-03  37.306270  -3.236022   2023-09-12   1
# 286159   0312 5199990  39.0  1989-06-12  44.021131  12.579491   2023-09-12   1
# 286131   0141-8520273  46.0  1985-04-29  58.522212  15.088656   2023-09-12   1
# 286130  070 7947 8473  44.0  1900-01-01  55.906269  -3.889257   2023-09-12   1
# 286129   0471-3323318  46.0  1979-12-17  56.783852  15.524003   2023-09-12   1
# ...               ...   ...         ...        ...        ...          ...  ..
# 143059  079 0467 9462  44.0  2000-09-15  52.872901  -4.016153   2023-09-12   1
# 143058  077 0934 3274  44.0  1900-01-01  56.260805  -5.346506   2023-09-12   1
# 143057   67 190 48 65  48.0  1977-06-01  53.359614  14.605133   2023-09-12   1
# 143056    724 173 146  34.0  1983-05-19  38.035674  -3.392758   2023-09-12   1
# 429186   0357 0654156  39.0  1993-11-23  37.151345  14.647698   2023-09-12   1
#
# [428846 rows x 18 columns]

# %%
target = session.table("SNF_MDRAZ.SILVER.CUSTOMER")
df_sp_bronze = session.create_dataframe(df_bronze)

merged = target.merge(
    source=df_sp_bronze,
    join_expr=(target['ID'] == df_sp_bronze['INDEX']),
    clauses= [
        when_matched().update(
            {
            "CUSTOMERID": df_sp_bronze['KUNNR'],
            "GENDER": df_sp_bronze['GENDE'], 
            "FIRSTNAME": df_sp_bronze['NAME1'], 
            "LASTNAME": df_sp_bronze['NAME2'], 
            "STREETADDRESS": df_sp_bronze['STRAS'], 
            "CITY": df_sp_bronze['ORT01'], 
            "POSTALCODE": df_sp_bronze['PSTLZ'], 
            "COUNTRYCODE": df_sp_bronze['LAND1'], 
            "COUNTRYNAME": df_sp_bronze['LAND2'], 
            "EMAILADDRESS": df_sp_bronze['RSCON'], 
            "PHONENUMBER": df_sp_bronze['TELF1'], 
            "PHONECOUNTRYCODE": df_sp_bronze['REGIO'], 
            "DATEOFBIRTH": df_sp_bronze['BIRTH'], 
            "LATITUDE": df_sp_bronze['LATI'], 
            "LONGITUDE": df_sp_bronze['LONG'], 
            "LASTMODIFIED": df_sp_bronze['LASTMODIFIED']
            }
        ),
        when_not_matched().insert(
            {
            "ID": df_sp_bronze['INDEX'], 
            "CUSTOMERID": df_sp_bronze['KUNNR'],
            "GENDER": df_sp_bronze['GENDE'], 
            "FIRSTNAME": df_sp_bronze['NAME1'], 
            "LASTNAME": df_sp_bronze['NAME2'], 
            "STREETADDRESS": df_sp_bronze['STRAS'], 
            "CITY": df_sp_bronze['ORT01'], 
            "POSTALCODE": df_sp_bronze['PSTLZ'], 
            "COUNTRYCODE": df_sp_bronze['LAND1'], 
            "COUNTRYNAME": df_sp_bronze['LAND2'], 
            "EMAILADDRESS": df_sp_bronze['RSCON'], 
            "PHONENUMBER": df_sp_bronze['TELF1'], 
            "PHONECOUNTRYCODE": df_sp_bronze['REGIO'], 
            "DATEOFBIRTH": df_sp_bronze['BIRTH'], 
            "LATITUDE": df_sp_bronze['LATI'], 
            "LONGITUDE": df_sp_bronze['LONG'], 
            "LASTMODIFIED": df_sp_bronze['LASTMODIFIED']
            }
        )
    ]
)

# %%
merged
# Out:
# MergeResult(rows_inserted=429187, rows_updated=0, rows_deleted=0)
