# %%
# Import login values from config
from configparser import *

# %%
# Import packages needed
from snowflake.snowpark import Session
from snowflake.snowpark.functions import *
from snowflake.snowpark.types import *
from snowflake.snowpark import Window
import pandas as pd
from urllib import request
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re

# %%
import sys, json
with open("connection_parameters_true.json") as jsonfile:
    credentials_dict = json.load(jsonfile)

# %%
def snowpark_session_create():
    session = Session.builder.configs(credentials_dict).create()
    return session

# %%
# Creation of session using the above function
demo_session = snowpark_session_create()

# %%
# TODO: Replace with values relevant to you
demo_session.use_database("snowpark")
demo_session.use_schema("gold")

# %% [markdown]
# ## Data

# %%
sales = demo_session.table("RAW_CREDITCO_SALES")
sales.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# |"INGESTION_ID"  |"INGESTED_AT"               |"DATA"                                              |
# ----------------------------------------------------------------------------------------------------
# |1               |2023-09-06 01:31:00.685000  |[                                                   |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "30211992825494",           |
# |                |                            |    "creditCardType": "diners-club-carte-blanche",  |
# |                |                            |    "dateTime": "2022-04-06 12:24:38",              |
# |                |                            |    "id": "bad9cffb24fd560624859ae0c21f9135f5b0...  |
# |                |                            |    "saleAmount": 302.2                             |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "4405443328071522",         |
# |                |                            |    "creditCardType": "visa-electron",              |
# |                |                            |    "dateTime": "2023-02-16 10:21:46",              |
# |                |                            |    "id": "f70a7d8263289ad52bc948916d4532521539...  |
# |                |                            |    "saleAmount": 279.17                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3579855610552574",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2022-06-01 23:16:18",              |
# |                |                            |    "id": "fb992d6a592ee80769f142fdaeb6334269f1...  |
# |                |                            |    "saleAmount": 445.47                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "50383603573914002",        |
# |                |                            |    "creditCardType": "maestro",                    |
# |                |                            |    "dateTime": "2022-06-29 01:56:53",              |
# |                |                            |    "id": "6dbdd40dfd3839e4da175301450ed500f6f7...  |
# |                |                            |    "saleAmount": 73.93                             |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5602228690840960",         |
# |                |                            |    "creditCardType": "bankcard",                   |
# |                |                            |    "dateTime": "2022-10-16 22:37:15",              |
# |                |                            |    "id": "e102d3a60180098cd3fcdbf5e08e461636ca...  |
# |                |                            |    "saleAmount": 640.69                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5100144013918382",         |
# |                |                            |    "creditCardType": "mastercard",                 |
# |                |                            |    "dateTime": "2023-01-18 21:32:30",              |
# |                |                            |    "id": "5291eb78808684cde42217736715cb29fb8a...  |
# |                |                            |    "saleAmount": 212.51                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3566731438126971",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2022-05-22 22:17:52",              |
# |                |                            |    "id": "be52606565faf06a546ca1eaf1873f2cbf4d...  |
# |                |                            |    "saleAmount": 633.21                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3552372594286931",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2022-12-15 01:17:57",              |
# |                |                            |    "id": "eeb62e335642e773c8c1ced13fe86c06e96d...  |
# |                |                            |    "saleAmount": 359.57                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5038306986883304079",      |
# |                |                            |    "creditCardType": "maestro",                    |
# |                |                            |    "dateTime": "2023-01-03 10:05:00",              |
# |                |                            |    "id": "ad187740d176791cd73aab91956c78974b72...  |
# |                |                            |    "saleAmount": 208.23                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3535351427856427",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2022-08-31 13:54:49",              |
# |                |                            |    "id": "61d49b03b011efc73e536560cc43f1d6c3a5...  |
# |                |                            |    "saleAmount": 725.71                            |
# |                |                            |  }                                                 |
# |                |                            |]                                                   |
# |2               |2023-09-06 01:36:17.344000  |[                                                   |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5508176932162294",         |
# |                |                            |    "creditCardType": "mastercard",                 |
# |                |                            |    "dateTime": "2022-05-05 23:57:28",              |
# |                |                            |    "id": "6929f37efca77ca1183de291878aeb01df7f...  |
# |                |                            |    "saleAmount": 104.31                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5100170235305322",         |
# |                |                            |    "creditCardType": "mastercard",                 |
# |                |                            |    "dateTime": "2022-11-17 15:32:08",              |
# |                |                            |    "id": "bc91529cf8c5dc0177f4187a7ac291343cf1...  |
# |                |                            |    "saleAmount": 507.77                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3589433589169560",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2023-02-15 10:07:31",              |
# |                |                            |    "id": "d6a5a2c3ceb5ffe288a16dd16ff55e243d4d...  |
# |                |                            |    "saleAmount": 170.02                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3555586629098303",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2023-01-04 01:34:06",              |
# |                |                            |    "id": "b076f6b41e238c45e63c7fe4d1f66fdda1d1...  |
# |                |                            |    "saleAmount": 501.04                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "6706100376371730",         |
# |                |                            |    "creditCardType": "laser",                      |
# |                |                            |    "dateTime": "2022-05-12 06:00:46",              |
# |                |                            |    "id": "1f57f83f7b42aa8a986d4b01f2b996669a75...  |
# |                |                            |    "saleAmount": 129.57                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5602247780904171",         |
# |                |                            |    "creditCardType": "bankcard",                   |
# |                |                            |    "dateTime": "2022-07-17 15:16:38",              |
# |                |                            |    "id": "6eda427326d9a3829621e73afb28ec924c86...  |
# |                |                            |    "saleAmount": 243.89                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3565858283414805",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2023-01-18 23:34:03",              |
# |                |                            |    "id": "06db982c6bf7d306cf16af3cd01316e3aefb...  |
# |                |                            |    "saleAmount": 505.83                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5641828030448807704",      |
# |                |                            |    "creditCardType": "switch",                     |
# |                |                            |    "dateTime": "2022-10-06 00:06:08",              |
# |                |                            |    "id": "8980dbde6642088242b8bf93e23d65d19c08...  |
# |                |                            |    "saleAmount": 614.5                             |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5108758559774396",         |
# |                |                            |    "creditCardType": "mastercard",                 |
# |                |                            |    "dateTime": "2022-11-07 13:12:44",              |
# |                |                            |    "id": "3e6d96ba37a3b92db0ebed1650da15ce078a...  |
# |                |                            |    "saleAmount": 729.55                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3531925498468842",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2022-12-09 21:29:21",              |
# |                |                            |    "id": "f03665c549c08f30e5b319f72c744d11b81a...  |
# |                |                            |    "saleAmount": 609.49                            |
# |                |                            |  }                                                 |
# |                |                            |]                                                   |
# |3               |2023-09-06 01:36:43.779000  |[                                                   |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3577254950335455",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2022-05-08 16:22:46",              |
# |                |                            |    "id": "ef9f2a1480245dcabe9a0028cf070c4c90e0...  |
# |                |                            |    "saleAmount": 302.38                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3554549240876508",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2023-04-02 12:06:35",              |
# |                |                            |    "id": "40c139b8fa3ef091e6872e968d129bdea930...  |
# |                |                            |    "saleAmount": 147.71                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "30266916616965",           |
# |                |                            |    "creditCardType": "diners-club-carte-blanche",  |
# |                |                            |    "dateTime": "2022-04-05 21:55:11",              |
# |                |                            |    "id": "455264f770f0bda6b412e399bb38acf4c7ff...  |
# |                |                            |    "saleAmount": 77.47                             |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "633451185597375535",       |
# |                |                            |    "creditCardType": "solo",                       |
# |                |                            |    "dateTime": "2022-11-16 09:32:35",              |
# |                |                            |    "id": "b060f868e3e72b1989e3b2407193e4f8b62d...  |
# |                |                            |    "saleAmount": 430.19                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3534118906250666",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2022-12-07 22:57:35",              |
# |                |                            |    "id": "99df14a00fb6f97e4c1c376bd9b5dc9b115f...  |
# |                |                            |    "saleAmount": 253.83                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3575177399469647",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2023-02-11 20:01:45",              |
# |                |                            |    "id": "28f8f23c5c0b5bc4c9eda8abf96ffe9f36e1...  |
# |                |                            |    "saleAmount": 564.36                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "6333020302312124279",      |
# |                |                            |    "creditCardType": "switch",                     |
# |                |                            |    "dateTime": "2023-03-09 11:22:30",              |
# |                |                            |    "id": "2ac5fe05ea1770a825e613e31e528f88af9c...  |
# |                |                            |    "saleAmount": 291.37                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3551078881931920",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2023-02-12 22:10:49",              |
# |                |                            |    "id": "67059c95cb922cd9146cbb7cb550861d4373...  |
# |                |                            |    "saleAmount": 565.97                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3537111546909475",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2023-03-16 06:46:57",              |
# |                |                            |    "id": "65c230303222a2466ead2a15b2210b933374...  |
# |                |                            |    "saleAmount": 209.55                            |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3557546242325275",         |
# |                |                            |    "creditCardType": "jcb",                        |
# |                |                            |    "dateTime": "2022-08-23 11:26:17",              |
# |                |                            |    "id": "3c3c0f2774b86361db8a5de484501788064f...  |
# |                |                            |    "saleAmount": 310.73                            |
# |                |                            |  }                                                 |
# |                |                            |]                                                   |
# ----------------------------------------------------------------------------------------------------

# %%
sale_items = demo_session.table("RAW_CREDITCO_SALES_ITEMS")
sale_items.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# |"INGESTION_ID"  |"INGESTED_AT"               |"DATA"                                              |
# ----------------------------------------------------------------------------------------------------
# |1               |2023-09-06 01:37:18.417000  |[                                                   |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "30211992825494",           |
# |                |                            |    "dateTime": "2022-04-06 12:24:38",              |
# |                |                            |    "id": "bad9cffb24fd560624859ae0c21f9135f5b0...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "T-shirt",                                    |
# |                |                            |      "Jeans",                                      |
# |                |                            |      "Sneakers"                                    |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "4405443328071522",         |
# |                |                            |    "dateTime": "2023-02-16 10:21:46",              |
# |                |                            |    "id": "f70a7d8263289ad52bc948916d4532521539...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Dress",                                      |
# |                |                            |      "Sandals"                                     |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3579855610552574",         |
# |                |                            |    "dateTime": "2022-06-01 23:16:18",              |
# |                |                            |    "id": "fb992d6a592ee80769f142fdaeb6334269f1...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Shirt",                                      |
# |                |                            |      "Shorts",                                     |
# |                |                            |      "Flip flops"                                  |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "50383603573914002",        |
# |                |                            |    "dateTime": "2022-06-29 01:56:53",              |
# |                |                            |    "id": "6dbdd40dfd3839e4da175301450ed500f6f7...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Blouse",                                     |
# |                |                            |      "Skirt",                                      |
# |                |                            |      "Heels"                                       |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5602228690840960",         |
# |                |                            |    "dateTime": "2022-10-16 22:37:15",              |
# |                |                            |    "id": "e102d3a60180098cd3fcdbf5e08e461636ca...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Sweater",                                    |
# |                |                            |      "Pants",                                      |
# |                |                            |      "Boots"                                       |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5100144013918382",         |
# |                |                            |    "dateTime": "2023-01-18 21:32:30",              |
# |                |                            |    "id": "5291eb78808684cde42217736715cb29fb8a...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Jacket",                                     |
# |                |                            |      "Jeans"                                       |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3566731438126971",         |
# |                |                            |    "dateTime": "2022-05-22 22:17:52",              |
# |                |                            |    "id": "be52606565faf06a546ca1eaf1873f2cbf4d...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Hoodie",                                     |
# |                |                            |      "Leggings",                                   |
# |                |                            |      "Sneakers"                                    |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3552372594286931",         |
# |                |                            |    "dateTime": "2022-12-15 01:17:57",              |
# |                |                            |    "id": "eeb62e335642e773c8c1ced13fe86c06e96d...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Polo shirt",                                 |
# |                |                            |      "Shorts",                                     |
# |                |                            |      "Sandals"                                     |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5038306986883304079",      |
# |                |                            |    "dateTime": "2023-01-03 10:05:00",              |
# |                |                            |    "id": "ad187740d176791cd73aab91956c78974b72...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Blue Jeans",                                 |
# |                |                            |      "White T-shirt",                              |
# |                |                            |      "Black Sneakers"                              |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3535351427856427",         |
# |                |                            |    "dateTime": "2022-08-31 13:54:49",              |
# |                |                            |    "id": "61d49b03b011efc73e536560cc43f1d6c3a5...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Striped Dress",                              |
# |                |                            |      "Silver Earrings",                            |
# |                |                            |      "Brown Sandals",                              |
# |                |                            |      "Leather Belt"                                |
# |                |                            |    ]                                               |
# |                |                            |  }                                                 |
# |                |                            |]                                                   |
# |2               |2023-09-06 01:37:18.417000  |[                                                   |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5508176932162294",         |
# |                |                            |    "dateTime": "2022-05-05 23:57:28",              |
# |                |                            |    "id": "6929f37efca77ca1183de291878aeb01df7f...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "T-shirt",                                    |
# |                |                            |      "Jeans"                                       |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5100170235305322",         |
# |                |                            |    "dateTime": "2022-11-17 15:32:08",              |
# |                |                            |    "id": "bc91529cf8c5dc0177f4187a7ac291343cf1...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "T-shirt",                                    |
# |                |                            |      "Jeans"                                       |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3589433589169560",         |
# |                |                            |    "dateTime": "2023-02-15 10:07:31",              |
# |                |                            |    "id": "d6a5a2c3ceb5ffe288a16dd16ff55e243d4d...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Sweater",                                    |
# |                |                            |      "Leggings",                                   |
# |                |                            |      "Boots"                                       |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3555586629098303",         |
# |                |                            |    "dateTime": "2023-01-04 01:34:06",              |
# |                |                            |    "id": "b076f6b41e238c45e63c7fe4d1f66fdda1d1...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Shirt",                                      |
# |                |                            |      "Shorts"                                      |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "6706100376371730",         |
# |                |                            |    "dateTime": "2022-05-12 06:00:46",              |
# |                |                            |    "id": "1f57f83f7b42aa8a986d4b01f2b996669a75...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Blouse",                                     |
# |                |                            |      "Skirt",                                      |
# |                |                            |      "Flats"                                       |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5602247780904171",         |
# |                |                            |    "dateTime": "2022-07-17 15:16:38",              |
# |                |                            |    "id": "6eda427326d9a3829621e73afb28ec924c86...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Hoodie",                                     |
# |                |                            |      "Joggers"                                     |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3565858283414805",         |
# |                |                            |    "dateTime": "2023-01-18 23:34:03",              |
# |                |                            |    "id": "06db982c6bf7d306cf16af3cd01316e3aefb...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Polo Shirt",                                 |
# |                |                            |      "Chinos"                                      |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5641828030448807704",      |
# |                |                            |    "dateTime": "2022-10-06 00:06:08",              |
# |                |                            |    "id": "8980dbde6642088242b8bf93e23d65d19c08...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Tank Top",                                   |
# |                |                            |      "Capri Pants"                                 |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "5108758559774396",         |
# |                |                            |    "dateTime": "2022-11-07 13:12:44",              |
# |                |                            |    "id": "3e6d96ba37a3b92db0ebed1650da15ce078a...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Jacket",                                     |
# |                |                            |      "Dress Pants"                                 |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3531925498468842",         |
# |                |                            |    "dateTime": "2022-12-09 21:29:21",              |
# |                |                            |    "id": "f03665c549c08f30e5b319f72c744d11b81a...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Cardigan",                                   |
# |                |                            |      "Maxi Dress",                                 |
# |                |                            |      "Sandals"                                     |
# |                |                            |    ]                                               |
# |                |                            |  }                                                 |
# |                |                            |]                                                   |
# |3               |2023-09-06 01:37:18.417000  |[                                                   |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3577254950335455",         |
# |                |                            |    "dateTime": "2022-05-08 16:22:46",              |
# |                |                            |    "id": "ef9f2a1480245dcabe9a0028cf070c4c90e0...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Sweatshirt",                                 |
# |                |                            |      "Cargo Pants"                                 |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3554549240876508",         |
# |                |                            |    "dateTime": "2023-04-02 12:06:35",              |
# |                |                            |    "id": "40c139b8fa3ef091e6872e968d129bdea930...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Tunic",                                      |
# |                |                            |      "Leggings",                                   |
# |                |                            |      "Ankle Boots"                                 |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "30266916616965",           |
# |                |                            |    "dateTime": "2022-04-05 21:55:11",              |
# |                |                            |    "id": "455264f770f0bda6b412e399bb38acf4c7ff...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Shawl",                                      |
# |                |                            |      "Denim Skirt"                                 |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "633451185597375535",       |
# |                |                            |    "dateTime": "2022-11-16 09:32:35",              |
# |                |                            |    "id": "b060f868e3e72b1989e3b2407193e4f8b62d...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Pullover",                                   |
# |                |                            |      "Sweatpants"                                  |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3534118906250666",         |
# |                |                            |    "dateTime": "2022-12-07 22:57:35",              |
# |                |                            |    "id": "99df14a00fb6f97e4c1c376bd9b5dc9b115f...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Blazer",                                     |
# |                |                            |      "Slacks",                                     |
# |                |                            |      "Loafers"                                     |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3575177399469647",         |
# |                |                            |    "dateTime": "2023-02-11 20:01:45",              |
# |                |                            |    "id": "28f8f23c5c0b5bc4c9eda8abf96ffe9f36e1...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Button-up Shirt",                            |
# |                |                            |      "Khakis"                                      |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "6333020302312124279",      |
# |                |                            |    "dateTime": "2023-03-09 11:22:30",              |
# |                |                            |    "id": "2ac5fe05ea1770a825e613e31e528f88af9c...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Vest",                                       |
# |                |                            |      "Jeans",                                      |
# |                |                            |      "Sneakers"                                    |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3551078881931920",         |
# |                |                            |    "dateTime": "2023-02-12 22:10:49",              |
# |                |                            |    "id": "67059c95cb922cd9146cbb7cb550861d4373...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Crop Top",                                   |
# |                |                            |      "Shorts"                                      |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3537111546909475",         |
# |                |                            |    "dateTime": "2023-03-16 06:46:57",              |
# |                |                            |    "id": "65c230303222a2466ead2a15b2210b933374...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Sweater Dress",                              |
# |                |                            |      "Tights",                                     |
# |                |                            |      "Heels"                                       |
# |                |                            |    ]                                               |
# |                |                            |  },                                                |
# |                |                            |  {                                                 |
# |                |                            |    "creditCardNumber": "3557546242325275",         |
# |                |                            |    "dateTime": "2022-08-23 11:26:17",              |
# |                |                            |    "id": "3c3c0f2774b86361db8a5de484501788064f...  |
# |                |                            |    "items": [                                      |
# |                |                            |      "Turtleneck",                                 |
# |                |                            |      "Corduroy Pants"                              |
# |                |                            |    ]                                               |
# |                |                            |  }                                                 |
# |                |                            |]                                                   |
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## UDF

# %%
sale_items_flat = (
    sale_items.join_table_function("flatten", col("data"))
    .withColumn("credit_card_number", json_extract_path_text("value", lit("creditCardNumber")))
    .withColumn("date_time", json_extract_path_text("value", lit("dateTime")))
    .withColumn("id", md5(json_extract_path_text("value", lit("id"))))
    .withColumn("items", json_extract_path_text("value", lit("items")))
    .select("ingestion_id","INGESTED_AT","credit_card_number","date_time","id","items")
)

sale_items_flat.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"INGESTION_ID"  |"INGESTED_AT"               |"CREDIT_CARD_NUMBER"  |"DATE_TIME"          |"ID"                              |"ITEMS"                                             |
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |1               |2023-09-06 01:37:18.417000  |30211992825494        |2022-04-06 12:24:38  |690863fd43c06792f23fdc2700ae090e  |["T-shirt","Jeans","Sneakers"]                      |
# |1               |2023-09-06 01:37:18.417000  |4405443328071522      |2023-02-16 10:21:46  |2b0de9a34332c8f27f11d07d11b4eaa2  |["Dress","Sandals"]                                 |
# |1               |2023-09-06 01:37:18.417000  |3579855610552574      |2022-06-01 23:16:18  |be83739b50b41880570c132f092d57ae  |["Shirt","Shorts","Flip flops"]                     |
# |1               |2023-09-06 01:37:18.417000  |50383603573914002     |2022-06-29 01:56:53  |7e25f863e835c2b79819a6a4f8e5ff98  |["Blouse","Skirt","Heels"]                          |
# |1               |2023-09-06 01:37:18.417000  |5602228690840960      |2022-10-16 22:37:15  |80d550a377048cce1270c0c025d1e91e  |["Sweater","Pants","Boots"]                         |
# |1               |2023-09-06 01:37:18.417000  |5100144013918382      |2023-01-18 21:32:30  |f54d9d5bf9fcddea178a9aa3cfa55a06  |["Jacket","Jeans"]                                  |
# |1               |2023-09-06 01:37:18.417000  |3566731438126971      |2022-05-22 22:17:52  |8e67ebae8673b905c051378a4012cfff  |["Hoodie","Leggings","Sneakers"]                    |
# |1               |2023-09-06 01:37:18.417000  |3552372594286931      |2022-12-15 01:17:57  |03461037872a2a49d7e17a26e590fc54  |["Polo shirt","Shorts","Sandals"]                   |
# |1               |2023-09-06 01:37:18.417000  |5038306986883304079   |2023-01-03 10:05:00  |69359a2361ebd3ba9e27a5dbdd4ec44f  |["Blue Jeans","White T-shirt","Black Sneakers"]     |
# |1               |2023-09-06 01:37:18.417000  |3535351427856427      |2022-08-31 13:54:49  |1aeea42a1a5233bb39f762191af256cc  |["Striped Dress","Silver Earrings","Brown Sanda...  |
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# TODO: Create an internal stage for our UDF
demo_session.sql("create or replace stage demo_stage").collect()
# Out:
# [Row(status='Stage area DEMO_STAGE successfully created.')]

# %%
# TODO: Place our UDF file in the internal stage
demo_session.file.put("udf.py","@demo_stage", auto_compress = False)
# Out:
# [PutResult(source='udf.py', target='udf.py', source_size=67, target_size=80, source_compression='NONE', target_compression='NONE', status='UPLOADED', message='')]

# %%
# TODO: Register the UDF from the stage
sort_alphabetically = demo_session.udf.register_from_file(
    file_path="@demo_stage/udf.py",
    func_name="sort_alphabetically",
    return_type=ArrayType(),
    input_types=[VariantType()],
    name="sort_alphabetically",
    replace=True,
    stage_location="@demo_stage",
    is_permanent=True
)

# %%
# TODO: Repeat the transformation above with the UDF
sale_items_flat_wudf = (
    sale_items.join_table_function("flatten", col("data"))
    .withColumn("credit_card_number", json_extract_path_text("value", lit("creditCardNumber")))
    .withColumn("date_time", json_extract_path_text("value", lit("dateTime")))
    .withColumn("id", md5(json_extract_path_text("value", lit("id"))))
    .withColumn("items", sort_alphabetically(parse_json(json_extract_path_text("value", lit("items")))))
    .select("ingestion_id","INGESTED_AT","credit_card_number","date_time","id","items")
)

# %%
# TODO: .show()
sale_items_flat_wudf.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# |"INGESTION_ID"  |"INGESTED_AT"               |"CREDIT_CARD_NUMBER"  |"DATE_TIME"          |"ID"                              |"ITEMS"               |
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# |1               |2023-09-06 01:37:18.417000  |30211992825494        |2022-04-06 12:24:38  |690863fd43c06792f23fdc2700ae090e  |[                     |
# |                |                            |                      |                     |                                  |  "Jeans",            |
# |                |                            |                      |                     |                                  |  "Sneakers",         |
# |                |                            |                      |                     |                                  |  "T-shirt"           |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |4405443328071522      |2023-02-16 10:21:46  |2b0de9a34332c8f27f11d07d11b4eaa2  |[                     |
# |                |                            |                      |                     |                                  |  "Dress",            |
# |                |                            |                      |                     |                                  |  "Sandals"           |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |3579855610552574      |2022-06-01 23:16:18  |be83739b50b41880570c132f092d57ae  |[                     |
# |                |                            |                      |                     |                                  |  "Flip flops",       |
# |                |                            |                      |                     |                                  |  "Shirt",            |
# |                |                            |                      |                     |                                  |  "Shorts"            |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |50383603573914002     |2022-06-29 01:56:53  |7e25f863e835c2b79819a6a4f8e5ff98  |[                     |
# |                |                            |                      |                     |                                  |  "Blouse",           |
# |                |                            |                      |                     |                                  |  "Heels",            |
# |                |                            |                      |                     |                                  |  "Skirt"             |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |5602228690840960      |2022-10-16 22:37:15  |80d550a377048cce1270c0c025d1e91e  |[                     |
# |                |                            |                      |                     |                                  |  "Boots",            |
# |                |                            |                      |                     |                                  |  "Pants",            |
# |                |                            |                      |                     |                                  |  "Sweater"           |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |5100144013918382      |2023-01-18 21:32:30  |f54d9d5bf9fcddea178a9aa3cfa55a06  |[                     |
# |                |                            |                      |                     |                                  |  "Jacket",           |
# |                |                            |                      |                     |                                  |  "Jeans"             |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |3566731438126971      |2022-05-22 22:17:52  |8e67ebae8673b905c051378a4012cfff  |[                     |
# |                |                            |                      |                     |                                  |  "Hoodie",           |
# |                |                            |                      |                     |                                  |  "Leggings",         |
# |                |                            |                      |                     |                                  |  "Sneakers"          |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |3552372594286931      |2022-12-15 01:17:57  |03461037872a2a49d7e17a26e590fc54  |[                     |
# |                |                            |                      |                     |                                  |  "Polo shirt",       |
# |                |                            |                      |                     |                                  |  "Sandals",          |
# |                |                            |                      |                     |                                  |  "Shorts"            |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |5038306986883304079   |2023-01-03 10:05:00  |69359a2361ebd3ba9e27a5dbdd4ec44f  |[                     |
# |                |                            |                      |                     |                                  |  "Black Sneakers",   |
# |                |                            |                      |                     |                                  |  "Blue Jeans",       |
# |                |                            |                      |                     |                                  |  "White T-shirt"     |
# |                |                            |                      |                     |                                  |]                     |
# |1               |2023-09-06 01:37:18.417000  |3535351427856427      |2022-08-31 13:54:49  |1aeea42a1a5233bb39f762191af256cc  |[                     |
# |                |                            |                      |                     |                                  |  "Brown Sandals",    |
# |                |                            |                      |                     |                                  |  "Leather Belt",     |
# |                |                            |                      |                     |                                  |  "Silver Earrings",  |
# |                |                            |                      |                     |                                  |  "Striped Dress"     |
# |                |                            |                      |                     |                                  |]                     |
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# TODO: Save as a table called `sales_items`
sale_items_flat_wudf.write.mode("overwrite").saveAsTable("sale_items")

# %% [markdown]
# ## Merge

# %%
# Read CSV
new_sales_item_data = pd.read_csv("new_sales_item_data.csv")

# %%
# Print the pandas DF
new_sales_item_data
# Out:
#     INGESTION_ID                 INGESTED_AT   CREDIT_CARD_NUMBER  \
# 0              3  2023-04-06 08:28:53.892000     3534118906250666
# 1              3  2023-04-06 08:28:53.892000     3575177399469647
# 2              3  2023-04-06 08:28:53.892000  6333020302312124279
# 3              3  2023-04-06 08:28:53.892000     3551078881931920
# 4              3  2023-04-06 08:28:53.892000     3537111546909475
# 5              3  2023-04-06 08:28:53.892000     3557546242325275
# 6              4  2023-04-11 09:30:15.123000     1234567890123456
# 7              4  2023-04-11 09:30:15.123000     9876543210987654
# 8              4  2023-04-11 09:30:15.123000     5678901234567890
# 9              4  2023-04-11 09:30:15.123000     9876543210123456
# 10             4  2023-04-11 09:30:15.123000     1234567890987654
# 11             4  2023-04-11 09:30:15.123000     5678901230987654
# 12             4  2023-04-11 09:30:15.123000     9876543210234567
# 13             4  2023-04-11 09:30:15.123000     1234567890876543
# 14             4  2023-04-11 09:30:15.123000     5678901234560987
# 15             4  2023-04-11 09:30:15.123000     9876543210123456
#
#               DATE_TIME                                ID  \
# 0   2022-12-07 22:57:35  4cd1974f5be885220ab629a5228c2ebf
# 1   2023-02-11 20:01:45  0aba79867bd7d7b7823264e9408d095b
# 2   2023-03-09 11:22:30  0484eb3108c06aed5e6a354e5203d721
# 3   2023-02-12 22:10:49  5ff7f4e02b59ad20f55f53b94a77368f
# 4   2023-03-16 06:46:57  4b48465f9060140312d689dfd076a71f
# 5   2022-08-23 11:26:17  cd1675b2f0e20c56c8ea1f3e47afc577
# 6   2023-04-10 18:15:30  83f15e2fbb7f1b2208ef8423f07f54e8
# 7   2023-04-09 21:45:10  f439b6fc0f0bc8f2317b36afbdca19f7
# 8   2023-04-08 14:30:45  3b095264fc87e528edf91e16f2d51cd1
# 9   2023-04-07 10:20:15  83ff2aa7d37d0e7836ca5cf6f5c5a5d2
# 10  2023-04-06 19:55:55  ecb252044b5ea0f679ee78ec1a129047
# 11  2023-04-05 08:40:30  6bc1bf76f56292e54ef33e8b51aa9d2f
# 12  2023-04-04 14:25:10  0fd4f83af3dcbd8940563b221f6866a4
# 13  2023-04-03 20:10:45  1be4a4e4f1b19883c773e3aebf3c2d75
# 14  2023-04-02 07:55:25  2623a98d2c07b9fde7c8d70e439b0c83
# 15  2023-04-01 15:40:10  9b7db8f94ba2464337e93bfa68b8d59a
#
#                                  ITEMS
# 0        ["Blazer","Slacks","Loafers"]
# 1         ["Button-up Shirt","Khakis"]
# 2          ["Vest","Jeans","Sneakers"]
# 3                ["Crop Top","Shorts"]
# 4   ["Sweater Dress","Tights","Heels"]
# 5      ["Turtleneck","Corduroy Pants"]
# 6       ["T-Shirt","Jeans","Sneakers"]
# 7        ["Hoodie","Leggings","Boots"]
# 8                  ["Dress","Sandals"]
# 9         ["Jacket","Pants","Loafers"]
# 10   ["Sweater","Shorts","Flip Flops"]
# 11          ["Blouse","Skirt","Heels"]
# 12     ["Tank Top","Shorts","Sandals"]
# 13    ["Hoodie","Leggings","Sneakers"]
# 14                 ["Dress","Sandals"]
# 15        ["Jacket","Pants","Loafers"]

# %%
# Write pandas to `new_sales_item_data` as a temp table and show the new Snowpark DF
new_sales_item_data_sp = demo_session.write_pandas(
    df = new_sales_item_data,
    table_name = "new_sales_item_data",
    overwrite=True,
    auto_create_table=True,
    table_type="temp",
    quote_identifiers=False
)

new_sales_item_data_sp.show()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"INGESTION_ID"  |"INGESTED_AT"               |"CREDIT_CARD_NUMBER"  |"DATE_TIME"          |"ID"                              |"ITEMS"                             |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |3               |2023-04-06 08:28:53.892000  |3534118906250666      |2022-12-07 22:57:35  |4cd1974f5be885220ab629a5228c2ebf  |["Blazer","Slacks","Loafers"]       |
# |3               |2023-04-06 08:28:53.892000  |3575177399469647      |2023-02-11 20:01:45  |0aba79867bd7d7b7823264e9408d095b  |["Button-up Shirt","Khakis"]        |
# |3               |2023-04-06 08:28:53.892000  |6333020302312124279   |2023-03-09 11:22:30  |0484eb3108c06aed5e6a354e5203d721  |["Vest","Jeans","Sneakers"]         |
# |3               |2023-04-06 08:28:53.892000  |3551078881931920      |2023-02-12 22:10:49  |5ff7f4e02b59ad20f55f53b94a77368f  |["Crop Top","Shorts"]               |
# |3               |2023-04-06 08:28:53.892000  |3537111546909475      |2023-03-16 06:46:57  |4b48465f9060140312d689dfd076a71f  |["Sweater Dress","Tights","Heels"]  |
# |3               |2023-04-06 08:28:53.892000  |3557546242325275      |2022-08-23 11:26:17  |cd1675b2f0e20c56c8ea1f3e47afc577  |["Turtleneck","Corduroy Pants"]     |
# |4               |2023-04-11 09:30:15.123000  |1234567890123456      |2023-04-10 18:15:30  |83f15e2fbb7f1b2208ef8423f07f54e8  |["T-Shirt","Jeans","Sneakers"]      |
# |4               |2023-04-11 09:30:15.123000  |9876543210987654      |2023-04-09 21:45:10  |f439b6fc0f0bc8f2317b36afbdca19f7  |["Hoodie","Leggings","Boots"]       |
# |4               |2023-04-11 09:30:15.123000  |5678901234567890      |2023-04-08 14:30:45  |3b095264fc87e528edf91e16f2d51cd1  |["Dress","Sandals"]                 |
# |4               |2023-04-11 09:30:15.123000  |9876543210123456      |2023-04-07 10:20:15  |83ff2aa7d37d0e7836ca5cf6f5c5a5d2  |["Jacket","Pants","Loafers"]        |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# TODO: Merge `sales_items` with `new_sales_item_data`
target = demo_session.table("sale_items")

merged = target.merge(
    source=new_sales_item_data_sp,
    join_expr=(target["id"] == new_sales_item_data_sp["id"]),
    clauses= [
        when_not_matched().insert(
            {
            "ingestion_id": new_sales_item_data_sp["ingestion_id"],
            "INGESTED_AT": new_sales_item_data_sp["INGESTED_AT"],
            "CREDIT_CARD_NUMBER": new_sales_item_data_sp["CREDIT_CARD_NUMBER"],
            "DATE_TIME": new_sales_item_data_sp["DATE_TIME"],
            "ID": new_sales_item_data_sp["ID"],
            "ITEMS": parse_json(new_sales_item_data_sp["ingestion_id"]),
            }
        )
    ]
)

# %%
# TODO: Run the below to see how many rows were inserted, updated and deleted
merged
# Out:
# MergeResult(rows_inserted=10, rows_updated=0, rows_deleted=0)

# %% [markdown]
# ## Reading from Stages

# %%
# TODO: Put the two json files into our `demo stage`
demo_session.file.put("new_sales_items.json", "@demo_stage", auto_compress=False)
demo_session.file.put("new_sales.json", "@demo_stage", auto_compress=False)
# Out:
# [PutResult(source='new_sales.json', target='new_sales.json', source_size=3260, target_size=3264, source_compression='NONE', target_compression='NONE', status='UPLOADED', message='')]

# %%
# TODO: Create a DataFrameReader to read `new_sales_items.json`
json = demo_session.read.options({"STRIP_OUTER_ARRAY": True}).json("@demo_stage/new_sales_items.json")
json.show()
# Out:
# ------------------------------------------------------
# |"$1"                                                |
# ------------------------------------------------------
# |{                                                   |
# |  "creditCardNumber": "3552372594286931",           |
# |  "dateTime": "2022-12-15 01:17:57",                |
# |  "id": "eeb62e335642e773c8c1ced13fe86c06e96d08...  |
# |  "items": [                                        |
# |    "Polo shirt",                                   |
# |    "Shorts",                                       |
# |    "Sandals"                                       |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "5038306986883304079",        |
# |  "dateTime": "2023-01-03 10:05:00",                |
# |  "id": "ad187740d176791cd73aab91956c78974b720a...  |
# |  "items": [                                        |
# |    "Blue Jeans",                                   |
# |    "White T-shirt",                                |
# |    "Black Sneakers"                                |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "3535351427856427",           |
# |  "dateTime": "2022-08-31 13:54:49",                |
# |  "id": "61d49b03b011efc73e536560cc43f1d6c3a553...  |
# |  "items": [                                        |
# |    "Striped Dress",                                |
# |    "Silver Earrings",                              |
# |    "Brown Sandals",                                |
# |    "Leather Belt"                                  |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "1234567812345678",           |
# |  "dateTime": "2022-09-15 10:20:30",                |
# |  "id": "a1b2c3d4e5f6a7b8c9d0e1f2a3b4c5d6e7f8a9...  |
# |  "items": [                                        |
# |    "T-shirt",                                      |
# |    "Jeans",                                        |
# |    "Sneakers"                                      |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "2345678923456789",           |
# |  "dateTime": "2022-10-25 11:30:15",                |
# |  "id": "b1c2d3e4f5a6b7c8d9e0f1a2b3c4d5e6f7a8b9...  |
# |  "items": [                                        |
# |    "Dress",                                        |
# |    "Sandals"                                       |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "3456789034567890",           |
# |  "dateTime": "2022-11-23 12:40:00",                |
# |  "id": "c1d2e3f4a5b6c7d8e9f0a1b2c3d4e5f6a7b8c9...  |
# |  "items": [                                        |
# |    "Shirt",                                        |
# |    "Shorts",                                       |
# |    "Flip flops"                                    |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "4567890145678901",           |
# |  "dateTime": "2023-01-18 13:20:35",                |
# |  "id": "d1e2f3a4b5c6d7e8f9a0b1c2d3e4f5a6b7c8d9...  |
# |  "items": [                                        |
# |    "Blouse",                                       |
# |    "Skirt",                                        |
# |    "Heels"                                         |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "5678901256789012",           |
# |  "dateTime": "2023-02-08 14:10:10",                |
# |  "id": "e1f2a3b4c5d6e7f8a9b0c1d2e3f4a5b6c7d8e9...  |
# |  "items": [                                        |
# |    "Sweater",                                      |
# |    "Pants",                                        |
# |    "Boots"                                         |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "6789012367890123",           |
# |  "dateTime": "2022-10-12 15:35:40",                |
# |  "id": "1a2b3c4d5e6f7a8b9c0d1e2f3a4b5c6d7e8f9a...  |
# |  "items": [                                        |
# |    "T-shirt",                                      |
# |    "Jeans",                                        |
# |    "Sneakers"                                      |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "7890123478901234",           |
# |  "dateTime": "2022-11-22 16:45:25",                |
# |  "id": "2a3b4c5d6e7f8a9b0c1d2e3f4a5b6c7d8e9f0a...  |
# |  "items": [                                        |
# |    "Dress",                                        |
# |    "Sandals"                                       |
# |  ]                                                 |
# |}                                                   |
# ------------------------------------------------------

# %% [markdown]
# ## Automated ELT Snowpark

# %%
# Run the below to create our `transformed` table
extract_sales = (
    sales
    .join_table_function("flatten", col("data"))
    .withColumn("credit_card_number", json_extract_path_text("value", lit("creditCardNumber")))
    .withColumn("credit_card_type", json_extract_path_text("value", lit("creditCardType")))
    .withColumn("date_time", json_extract_path_text("value", lit("dateTime")))
    .withColumn("id", md5(json_extract_path_text("value", lit("id"))))
    .withColumn("sale_amount", json_extract_path_text("value", lit("saleAmount")))
    .select("credit_card_number", "credit_card_type", "date_time", "id", "sale_amount")
)

extract_sales_items = (
    sale_items
    .join_table_function("flatten", col("data"))
    .withColumn("credit_card_number", json_extract_path_text("value", lit("creditCardNumber")))
    .withColumn("date_time", json_extract_path_text("value", lit("dateTime")))
    .withColumn("id", md5(json_extract_path_text("value", lit("id"))))
    .withColumn("items", sort_alphabetically(parse_json(json_extract_path_text("value", lit("items")))))
    .select("credit_card_number", "date_time", "id", "items")
)

join_sales_and_sales_items = (
    extract_sales.join(
        right= extract_sales_items,
        on= extract_sales.id == extract_sales_items.id,
        rsuffix = "_si"
    )
    .select(
        "credit_card_number",
        "date_time", "id", "items",
        "sale_amount"
    )
)

join_sales_and_sales_items.write.mode("overwrite").save_as_table(
    table_name = "sales_data"
)

# %%
# TODO: Run and show
join_sales_and_sales_items.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# |"CREDIT_CARD_NUMBER"  |"DATE_TIME"          |"ID"                              |"ITEMS"               |"SALE_AMOUNT"  |
# ------------------------------------------------------------------------------------------------------------------------
# |30211992825494        |2022-04-06 12:24:38  |690863fd43c06792f23fdc2700ae090e  |[                     |302.2          |
# |                      |                     |                                  |  "Jeans",            |               |
# |                      |                     |                                  |  "Sneakers",         |               |
# |                      |                     |                                  |  "T-shirt"           |               |
# |                      |                     |                                  |]                     |               |
# |4405443328071522      |2023-02-16 10:21:46  |2b0de9a34332c8f27f11d07d11b4eaa2  |[                     |279.17         |
# |                      |                     |                                  |  "Dress",            |               |
# |                      |                     |                                  |  "Sandals"           |               |
# |                      |                     |                                  |]                     |               |
# |3579855610552574      |2022-06-01 23:16:18  |be83739b50b41880570c132f092d57ae  |[                     |445.47         |
# |                      |                     |                                  |  "Flip flops",       |               |
# |                      |                     |                                  |  "Shirt",            |               |
# |                      |                     |                                  |  "Shorts"            |               |
# |                      |                     |                                  |]                     |               |
# |50383603573914002     |2022-06-29 01:56:53  |7e25f863e835c2b79819a6a4f8e5ff98  |[                     |73.93          |
# |                      |                     |                                  |  "Blouse",           |               |
# |                      |                     |                                  |  "Heels",            |               |
# |                      |                     |                                  |  "Skirt"             |               |
# |                      |                     |                                  |]                     |               |
# |5602228690840960      |2022-10-16 22:37:15  |80d550a377048cce1270c0c025d1e91e  |[                     |640.69         |
# |                      |                     |                                  |  "Boots",            |               |
# |                      |                     |                                  |  "Pants",            |               |
# |                      |                     |                                  |  "Sweater"           |               |
# |                      |                     |                                  |]                     |               |
# |5100144013918382      |2023-01-18 21:32:30  |f54d9d5bf9fcddea178a9aa3cfa55a06  |[                     |212.51         |
# |                      |                     |                                  |  "Jacket",           |               |
# |                      |                     |                                  |  "Jeans"             |               |
# |                      |                     |                                  |]                     |               |
# |3566731438126971      |2022-05-22 22:17:52  |8e67ebae8673b905c051378a4012cfff  |[                     |633.21         |
# |                      |                     |                                  |  "Hoodie",           |               |
# |                      |                     |                                  |  "Leggings",         |               |
# |                      |                     |                                  |  "Sneakers"          |               |
# |                      |                     |                                  |]                     |               |
# |3552372594286931      |2022-12-15 01:17:57  |03461037872a2a49d7e17a26e590fc54  |[                     |359.57         |
# |                      |                     |                                  |  "Polo shirt",       |               |
# |                      |                     |                                  |  "Sandals",          |               |
# |                      |                     |                                  |  "Shorts"            |               |
# |                      |                     |                                  |]                     |               |
# |5038306986883304079   |2023-01-03 10:05:00  |69359a2361ebd3ba9e27a5dbdd4ec44f  |[                     |208.23         |
# |                      |                     |                                  |  "Black Sneakers",   |               |
# |                      |                     |                                  |  "Blue Jeans",       |               |
# |                      |                     |                                  |  "White T-shirt"     |               |
# |                      |                     |                                  |]                     |               |
# |3535351427856427      |2022-08-31 13:54:49  |1aeea42a1a5233bb39f762191af256cc  |[                     |725.71         |
# |                      |                     |                                  |  "Brown Sandals",    |               |
# |                      |                     |                                  |  "Leather Belt",     |               |
# |                      |                     |                                  |  "Silver Earrings",  |               |
# |                      |                     |                                  |  "Striped Dress"     |               |
# |                      |                     |                                  |]                     |               |
# ------------------------------------------------------------------------------------------------------------------------

# %%
new_sales_items = demo_session.read.options({"STRIP_OUTER_ARRAY":True}).json("@demo_stage/new_sales_items.json")
new_sales_items.show()
# Out:
# ------------------------------------------------------
# |"$1"                                                |
# ------------------------------------------------------
# |{                                                   |
# |  "creditCardNumber": "3552372594286931",           |
# |  "dateTime": "2022-12-15 01:17:57",                |
# |  "id": "eeb62e335642e773c8c1ced13fe86c06e96d08...  |
# |  "items": [                                        |
# |    "Polo shirt",                                   |
# |    "Shorts",                                       |
# |    "Sandals"                                       |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "5038306986883304079",        |
# |  "dateTime": "2023-01-03 10:05:00",                |
# |  "id": "ad187740d176791cd73aab91956c78974b720a...  |
# |  "items": [                                        |
# |    "Blue Jeans",                                   |
# |    "White T-shirt",                                |
# |    "Black Sneakers"                                |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "3535351427856427",           |
# |  "dateTime": "2022-08-31 13:54:49",                |
# |  "id": "61d49b03b011efc73e536560cc43f1d6c3a553...  |
# |  "items": [                                        |
# |    "Striped Dress",                                |
# |    "Silver Earrings",                              |
# |    "Brown Sandals",                                |
# |    "Leather Belt"                                  |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "1234567812345678",           |
# |  "dateTime": "2022-09-15 10:20:30",                |
# |  "id": "a1b2c3d4e5f6a7b8c9d0e1f2a3b4c5d6e7f8a9...  |
# |  "items": [                                        |
# |    "T-shirt",                                      |
# |    "Jeans",                                        |
# |    "Sneakers"                                      |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "2345678923456789",           |
# |  "dateTime": "2022-10-25 11:30:15",                |
# |  "id": "b1c2d3e4f5a6b7c8d9e0f1a2b3c4d5e6f7a8b9...  |
# |  "items": [                                        |
# |    "Dress",                                        |
# |    "Sandals"                                       |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "3456789034567890",           |
# |  "dateTime": "2022-11-23 12:40:00",                |
# |  "id": "c1d2e3f4a5b6c7d8e9f0a1b2c3d4e5f6a7b8c9...  |
# |  "items": [                                        |
# |    "Shirt",                                        |
# |    "Shorts",                                       |
# |    "Flip flops"                                    |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "4567890145678901",           |
# |  "dateTime": "2023-01-18 13:20:35",                |
# |  "id": "d1e2f3a4b5c6d7e8f9a0b1c2d3e4f5a6b7c8d9...  |
# |  "items": [                                        |
# |    "Blouse",                                       |
# |    "Skirt",                                        |
# |    "Heels"                                         |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "5678901256789012",           |
# |  "dateTime": "2023-02-08 14:10:10",                |
# |  "id": "e1f2a3b4c5d6e7f8a9b0c1d2e3f4a5b6c7d8e9...  |
# |  "items": [                                        |
# |    "Sweater",                                      |
# |    "Pants",                                        |
# |    "Boots"                                         |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "6789012367890123",           |
# |  "dateTime": "2022-10-12 15:35:40",                |
# |  "id": "1a2b3c4d5e6f7a8b9c0d1e2f3a4b5c6d7e8f9a...  |
# |  "items": [                                        |
# |    "T-shirt",                                      |
# |    "Jeans",                                        |
# |    "Sneakers"                                      |
# |  ]                                                 |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "7890123478901234",           |
# |  "dateTime": "2022-11-22 16:45:25",                |
# |  "id": "2a3b4c5d6e7f8a9b0c1d2e3f4a5b6c7d8e9f0a...  |
# |  "items": [                                        |
# |    "Dress",                                        |
# |    "Sandals"                                       |
# |  ]                                                 |
# |}                                                   |
# ------------------------------------------------------

# %%
# TODO: Create DataFrameReaders of the two .json files in our stage
new_sales_items = demo_session.read.options({"STRIP_OUTER_ARRAY":True}).json("@demo_stage/new_sales_items.json")
new_sales_items = new_sales_items.withColumnRenamed("$1", "data")

new_sales_items.write.mode("overwrite").save_as_table(
    table_name="new_sales_items_transient",
    table_type="transient",
)

new_sales = demo_session.read.options({"STRIP_OUTER_ARRAY":True}).json("@demo_stage/new_sales.json")
new_sales = new_sales.withColumnRenamed("$1", "data")

new_sales.write.mode("overwrite").save_as_table(
    table_name="new_sales_transient",
    table_type="transient",
)

# %%
new_sales.show()
# Out:
# ------------------------------------------------------
# |"DATA"                                              |
# ------------------------------------------------------
# |{                                                   |
# |  "creditCardNumber": "3551078881931920",           |
# |  "creditCardType": "jcb",                          |
# |  "dateTime": "2023-02-12 22:10:49",                |
# |  "id": "67059c95cb922cd9146cbb7cb550861d437383...  |
# |  "saleAmount": 565.97                              |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "3537111546909475",           |
# |  "creditCardType": "jcb",                          |
# |  "dateTime": "2023-03-16 06:46:57",                |
# |  "id": "65c230303222a2466ead2a15b2210b9333746b...  |
# |  "saleAmount": 209.55                              |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "3557546242325275",           |
# |  "creditCardType": "jcb",                          |
# |  "dateTime": "2022-08-23 11:26:17",                |
# |  "id": "3c3c0f2774b86361db8a5de484501788064f73...  |
# |  "saleAmount": 310.73                              |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "1234567812345678",           |
# |  "creditCardType": "visa",                         |
# |  "dateTime": "2022-05-10 10:30:45",                |
# |  "id": "a1b2c3d4e5f6a7b8c9d0e1f2a3b4c5d6e7f8a9...  |
# |  "saleAmount": 100.25                              |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "2345678923456789",           |
# |  "creditCardType": "mastercard",                   |
# |  "dateTime": "2022-06-20 11:45:20",                |
# |  "id": "0a1b2c3d4e5f6a7b8c9d0e1f2a3b4c5d6e7f8a...  |
# |  "saleAmount": 200.5                               |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "3456789034567890",           |
# |  "creditCardType": "american_express",             |
# |  "dateTime": "2022-07-30 12:20:55",                |
# |  "id": "9a8b7c6d5e4f3a2b1c0d9e8f7a6b5c4d3e2f1a...  |
# |  "saleAmount": 300.75                              |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "4567890145678901",           |
# |  "creditCardType": "discover",                     |
# |  "dateTime": "2022-08-31 13:55:30",                |
# |  "id": "8a9b7c6d5e4f3a2b1c0d9e8f7a6b5c4d3e2f1a...  |
# |  "saleAmount": 400.2                               |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "5678901256789012",           |
# |  "creditCardType": "jcb",                          |
# |  "dateTime": "2022-09-10 14:30:05",                |
# |  "id": "7a9b6c5d4e3f2a1b0c9d8e7f6a5b4c3d2e1f0a...  |
# |  "saleAmount": 500.1                               |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "6789012367890123",           |
# |  "creditCardType": "diners_club",                  |
# |  "dateTime": "2022-10-12 15:35:40",                |
# |  "id": "1a2b3c4d5e6f7a8b9c0d1e2f3a4b5c6d7e8f9a...  |
# |  "saleAmount": 600.15                              |
# |}                                                   |
# |{                                                   |
# |  "creditCardNumber": "7890123478901234",           |
# |  "creditCardType": "union_pay",                    |
# |  "dateTime": "2022-11-22 16:45:25",                |
# |  "id": "2a3b4c5d6e7f8a9b0c1d2e3f4a5b6c7d8e9f0a...  |
# |  "saleAmount": 700.25                              |
# |}                                                   |
# ------------------------------------------------------

# %%
# TODO: Transform the new data as you did the old data
extract_new_sales = (
    demo_session.table("NEW_SALES_TRANSIENT")
    .withColumn("credit_card_number", json_extract_path_text("data", lit("creditCardNumber")))
    .withColumn("credit_card_type", json_extract_path_text("data", lit("credit_card_type")))
    .withColumn("date_time", json_extract_path_text("data", lit("dateTime")))
    .withColumn("id", md5(json_extract_path_text("data", lit("id"))))
    .withColumn("sale_amount", json_extract_path_text("data", lit("saleAmount")))
    .select("credit_card_number","credit_card_type","date_time","id","sale_amount")
)

extract_new_sales_items = (
    demo_session.table("new_sales_items_transient")
    .withColumn("credit_card_number", json_extract_path_text("data", lit("creditCardNumber")))
    .withColumn("date_time", json_extract_path_text("data", lit("dateTime")))
    .withColumn("id", md5(json_extract_path_text("data", lit("id"))))
    .withColumn("items", sort_alphabetically(parse_json(json_extract_path_text("data", lit("items")))))
    .select("credit_card_number","date_time","id","items")
)

join_new_sales_and_sales_items = (
    extract_new_sales.join(
        right= extract_new_sales_items,
        on= extract_new_sales.id == extract_new_sales_items.id,
        rsuffix="_si"
    )
    .select(
        "credit_card_number",
        "date_time",
        "id",
        "items",
        "sale_amount"
    )
)

join_new_sales_and_sales_items.show()
# Out:
# -------------------------------------------------------------------------------------------------------------------
# |"CREDIT_CARD_NUMBER"  |"DATE_TIME"          |"ID"                              |"ITEMS"          |"SALE_AMOUNT"  |
# -------------------------------------------------------------------------------------------------------------------
# |1234567812345678      |2022-05-10 10:30:45  |720a209f737489338e85c86339bbc080  |[                |100.25         |
# |                      |                     |                                  |  "Jeans",       |               |
# |                      |                     |                                  |  "Sneakers",    |               |
# |                      |                     |                                  |  "T-shirt"      |               |
# |                      |                     |                                  |]                |               |
# |6789012367890123      |2022-10-12 15:35:40  |5d14cbe23215c81c7e155b1c97154020  |[                |600.15         |
# |                      |                     |                                  |  "Jeans",       |               |
# |                      |                     |                                  |  "Sneakers",    |               |
# |                      |                     |                                  |  "T-shirt"      |               |
# |                      |                     |                                  |]                |               |
# |7890123478901234      |2022-11-22 16:45:25  |90c0cd5cfcadac5d27442d5b63ee6772  |[                |700.25         |
# |                      |                     |                                  |  "Dress",       |               |
# |                      |                     |                                  |  "Sandals"      |               |
# |                      |                     |                                  |]                |               |
# |8901234589012345      |2022-12-20 17:55:10  |9d281f1ba93dc9553fcbd96a0059dd0c  |[                |800.3          |
# |                      |                     |                                  |  "Flip flops",  |               |
# |                      |                     |                                  |  "Shirt",       |               |
# |                      |                     |                                  |  "Shorts"       |               |
# |                      |                     |                                  |]                |               |
# |9012345690123456      |2023-01-15 18:35:45  |5f37cde8af23658c96ece5f86847d1cc  |[                |900.45         |
# |                      |                     |                                  |  "Blouse",      |               |
# |                      |                     |                                  |  "Heels",       |               |
# |                      |                     |                                  |  "Skirt"        |               |
# |                      |                     |                                  |]                |               |
# |0123456789012345      |2023-02-05 19:25:20  |2181cb22b6de88ca2638b65f82415d3b  |[                |1000.5         |
# |                      |                     |                                  |  "Boots",       |               |
# |                      |                     |                                  |  "Pants",       |               |
# |                      |                     |                                  |  "Sweater"      |               |
# |                      |                     |                                  |]                |               |
# -------------------------------------------------------------------------------------------------------------------

# %%
# TODO: Merge the new data into the old
target = demo_session.table("sales_data")

merged = target.merge(
    source= join_new_sales_and_sales_items,
    join_expr= (target["ID"] == join_new_sales_and_sales_items["ID"]),
    clauses= [
        when_not_matched().insert(
            {
                "credit_card_number": join_new_sales_and_sales_items["credit_card_number"],
                "date_time": join_new_sales_and_sales_items["date_time"],
                "id": join_new_sales_and_sales_items["id"],
                "items": join_new_sales_and_sales_items["items"],
                "sale_amount": join_new_sales_and_sales_items["sale_amount"],
            }
        )
    ]
)

merged
# Out:
# MergeResult(rows_inserted=6, rows_updated=0, rows_deleted=0)

# %%
# TODO: Drop the transient tables
demo_session.table("NEW_SALES_TRANSIENT").drop_table()
demo_session.table("NEW_SALES_ITEMS_TRANSIENT").drop_table()
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[61], line 2
#       1 # TODO: Drop the transient tables
# ----> 2 demo_session.table("NEW_SALES_TRANSIENT").drop_table()
#       3 demo_session.table("NEW_SALES_ITEMS_TRANSIENT").drop_table()
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\table.py:667, in Table.drop_table(self)
#     661 def drop_table(self) -> None:
#     662     """Drops the table from the Snowflake database.
#     663
#     664     Note that subsequent operations such as :meth:`DataFrame.select`, :meth:`DataFrame.collect` on this ``Table`` instance and the derived DataFrame will raise errors because the underlying
#     665     table in the Snowflake database no longer exists.
#     666     """
# --> 667     self._session.sql(
#     668         f"drop table {self.table_name}"
#     669     )._internal_collect_with_tag_no_telemetry()
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\dataframe.py:633, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive)
#     621 def _internal_collect_with_tag_no_telemetry(
#     622     self,
#     623     *,
#    (...)
#     631     # we should always call this method instead of collect(), to make sure the
#     632     # query tag is set properly.
# --> 633     return self._session._conn.execute(
#     634         self._plan,
#     635         block=block,
#     636         data_type=data_type,
#     637         _statement_params=create_or_update_statement_params_with_query_tag(
#     638             statement_params or self._statement_params,
#     639             self._session.query_tag,
#     640             SKIP_LEVELS_THREE,
#     641         ),
#     642         log_on_exception=log_on_exception,
#     643         case_sensitive=case_sensitive,
#     644     )
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:451, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     441 if (
#     442     is_in_stored_procedure()
#     443     and not block
#    (...)
#     446     )
#     447 ):  # pragma: no cover
#     448     raise NotImplementedError(
#     449         "Async query is not supported in stored procedure yet"
#     450     )
# --> 451 result_set, result_meta = self.get_result_set(
#     452     plan,
#     453     to_pandas,
#     454     to_iter,
#     455     **kwargs,
#     456     block=block,
#     457     data_type=data_type,
#     458     log_on_exception=log_on_exception,
#     459     case_sensitive=case_sensitive,
#     460 )
#     461 if not block:
#     462     return result_set
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:181, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     177 else:
#     178     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     179         e
#     180     )
# --> 181     raise ne.with_traceback(tb) from None
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:111, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     109 def wrap(*args, **kwargs):
#     110     try:
# --> 111         return func(*args, **kwargs)
#     112     except snowflake.connector.errors.ProgrammingError as e:
#     113         query = None
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:552, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     550 for holder, id_ in placeholders.items():
#     551     final_query = final_query.replace(holder, id_)
# --> 552 result = self.run_query(
#     553     final_query,
#     554     to_pandas,
#     555     to_iter and (i == len(plan.queries) - 1),
#     556     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     557     block=not is_last,
#     558     data_type=data_type,
#     559     async_job_plan=plan,
#     560     log_on_exception=log_on_exception,
#     561     case_sensitive=case_sensitive,
#     562     params=query.params,
#     563     **kwargs,
#     564 )
#     565 placeholders[query.query_id_place_holder] = (
#     566     result["sfqid"] if not is_last else result.query_id
#     567 )
#     568 result_meta = self._cursor.description
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:102, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      98     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#      99         ex.cause
#     100     )
#     101 except Exception as ex:
# --> 102     raise ex
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:96, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      94     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#      95 try:
# ---> 96     return func(*args, **kwargs)
#      97 except ReauthenticationRequest as ex:
#      98     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#      99         ex.cause
#     100     )
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:366, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, **kwargs)
#     364         query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     365         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 366     raise ex
#     368 # fetch_pandas_all/batches() only works for SELECT statements
#     369 # We call fetchall() if fetch_pandas_all/batches() fails,
#     370 # because when the query plan has multiple queries, it will
#     371 # have non-select statements, and it shouldn't fail if the user
#     372 # calls to_pandas() to execute the query.
#     373 if block:
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:347, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, **kwargs)
#     345     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     346 if block:
# --> 347     results_cursor = self._cursor.execute(query, params=params, **kwargs)
#     348     self.notify_query_listeners(
#     349         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     350     )
#     351     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\connector\cursor.py:908, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#     904     is_integrity_error = (
#     905         code == "100072"
#     906     )  # NULL result in a non-nullable column
#     907     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 908     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     909 return self
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\connector\errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     267 @staticmethod
#     268 def errorhandler_wrapper(
#     269     connection: SnowflakeConnection | None,
#    (...)
#     272     error_value: dict[str, Any],
#     273 ) -> None:
#     274     """Error handler wrapper that calls the errorhandler method.
#     275
#     276     Args:
#    (...)
#     287         exception to the first handler in that order.
#     288     """
# --> 290     handed_over = Error.hand_to_other_handler(
#     291         connection,
#     292         cursor,
#     293         error_class,
#     294         error_value,
#     295     )
#     296     if not handed_over:
#     297         raise Error.errorhandler_make_exception(
#     298             error_class,
#     299             error_value,
#     300         )
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\connector\errors.py:345, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     343 if cursor is not None:
#     344     cursor.messages.append((error_class, error_value))
# --> 345     cursor.errorhandler(connection, cursor, error_class, error_value)
#     346     return True
#     347 elif connection is not None:
#
# File c:\Users\mdraz\AppData\Local\Programs\Python\Python38\lib\site-packages\snowflake\connector\errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     219 errno = error_value.get("errno")
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# SnowparkSQLException: (1304): 01aece67-3201-f110-0000-000238ee7571: 002003 (42S02): SQL compilation error:
# Table 'SNOWPARK.GOLD.NEW_SALES_TRANSIENT' does not exist or not authorized.

# %%
# TODO: Remove the files from the stage
demo_session.sql("Remove @demo_stage/new_sales_items.json").collect()
demo_session.sql("Remove @demo_stage/new_sales.json").collect()
# Out:
# [Row(name='demo_stage/new_sales.json', result='removed')]

# %%
demo_session.close()
